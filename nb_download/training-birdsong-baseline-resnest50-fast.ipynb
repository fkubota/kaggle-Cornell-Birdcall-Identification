# %% [markdown]
# # Birdsong Pytorch Baseline: ResNeSt50-fast (Training)

# %% [markdown]
# ## About
#
# In this notebook, I try ResNeSt, which is the one of state of the art in image recognition.
#
# For the fair comparison with @hidehisaarai1213 's [great baseline](https://www.kaggle.com/hidehisaarai1213/inference-pytorch-birdcall-resnet-baseline), I used a model with the same depth and as the same experimental settings as possible. But There are some differences mainly because of the GPU resource limitation.
#
# The experimental settings are as follows:
#
# * Randomly crop 5 seconds for each train audio clip each epoch.
# * No augmentation.
# * Used pretrained weight of _`ResNeSt50-fast-1s1x64d`_ provided by the authors at [their repository](https://github.com/zhanghang1989/ResNeSt).
# * Used `BCELoss`
# * Trained **_50_** epoch and saved the weight which got best **_loss_** (this is because f1 score relies on thresholds.)
# * `Adam` optimizer (`lr=0.001`) with `CosineAnnealingLR` (`T_max=10`).
# * Used `StratifiedKFold(n_splits=5)` to split dataset and used only first fold
# * `batch_size`: **_50_**
# * melspectrogram parameters
#   - `n_mels`: 128
#   - `fmin`: 20
#   - `fmax`: 16000
# * image size: 224x547
#
# I forked a lot of codes such as preprocessing from @hidehisaarai1213 's [notebook](https://www.kaggle.com/hidehisaarai1213/inference-pytorch-birdcall-resnet-baseline) and [GitHub repository](https://github.com/koukyo1994/kaggle-birdcall-resnet-baseline-training). Many thanks!!!
#
#
# ### Note
#
# #### about dataset
# I prepared resmpaled train dataset for this notebook, see more details in:
# https://www.kaggle.com/c/birdsong-recognition/discussion/164197
#
#
# #### about custom packages
# In this **_training notebook_**, I used two custom packages, `pytorch-pfn-extras` for training and the authors' official implementation of `ResNeSt` for building model.
# On the other hand, as stated in [code requirements](https://www.kaggle.com/c/birdsong-recognition/overview/code-requirements), participants are **not allowed** to use custom packages in **_submission notebook_**.
#
# If you fork this notebook, keep the above things in mind.
#
#
# ### Reference
#
# #### ResNeSt: Split-Attention Networks
# * author: Hang Zhang, Chongruo Wu, Zhongyue Zhang, Yi Zhu, Zhi Zhang, Haibin Lin, Yue Sun, Tong He, Jonas Muller, R. Manmatha, Mu Li and Alex Smola
# * paper: [arXiv 2004.08955](https://arxiv.org/abs/2004.08955)
# * code: [GitHub](https://github.com/koukyo1994/kaggle-birdcall-resnet-baseline-training)
#
# #### pytorch-pfn-extras
# * author: Preferred Networks, Inc.
# * code: [GitHub](https://github.com/pfnet/pytorch-pfn-extras)

# %% [markdown]
# ## Prepare

# %% [markdown]
# ### import libraries

# %%
# %%bash
# pip install ../input/pytorch-pfn-extras/pytorch-pfn-extras-0.2.1/
# Out:
# Processing /kaggle/input/pytorch-pfn-extras/pytorch-pfn-extras-0.2.1
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from pytorch-pfn-extras==0.2.1) (1.18.1)
# Requirement already satisfied: torch in /opt/conda/lib/python3.7/site-packages (from pytorch-pfn-extras==0.2.1) (1.5.0)
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from torch->pytorch-pfn-extras==0.2.1) (0.18.2)
# Building wheels for collected packages: pytorch-pfn-extras
#   Building wheel for pytorch-pfn-extras (setup.py): started
#   Building wheel for pytorch-pfn-extras (setup.py): finished with status 'done'
#   Created wheel for pytorch-pfn-extras: filename=pytorch_pfn_extras-0.2.1-py3-none-any.whl size=61392 sha256=31a8d1b1a828e37c98050c4863e79bdbec781af45151db86f1cbbe304143898b
#   Stored in directory: /root/.cache/pip/wheels/4b/6d/96/1a021d23511ce1a377638f67ba1b0d8d1832fbcd3f0c6c1442
# Successfully built pytorch-pfn-extras
# Installing collected packages: pytorch-pfn-extras
# Successfully installed pytorch-pfn-extras-0.2.1

# %%
# %%bash
# pip install ../input/resnest50-fast-package/resnest-0.0.6b20200701/resnest/
# Out:
# Processing /kaggle/input/resnest50-fast-package/resnest-0.0.6b20200701/resnest
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from resnest==0.0.6b20200705) (1.18.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.7/site-packages (from resnest==0.0.6b20200705) (4.45.0)
# Requirement already satisfied: nose in /opt/conda/lib/python3.7/site-packages (from resnest==0.0.6b20200705) (1.3.7)
# Requirement already satisfied: torch>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from resnest==0.0.6b20200705) (1.5.0)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.7/site-packages (from resnest==0.0.6b20200705) (5.4.1)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from resnest==0.0.6b20200705) (1.4.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from resnest==0.0.6b20200705) (2.23.0)
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from torch>=1.0.0->resnest==0.0.6b20200705) (0.18.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->resnest==0.0.6b20200705) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->resnest==0.0.6b20200705) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->resnest==0.0.6b20200705) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->resnest==0.0.6b20200705) (2.9)
# Building wheels for collected packages: resnest
#   Building wheel for resnest (setup.py): started
#   Building wheel for resnest (setup.py): finished with status 'done'
#   Created wheel for resnest: filename=resnest-0.0.6b20200705-py3-none-any.whl size=31062 sha256=13aee3c4d76ae895cf831b2fe7ca3430c0b629fc4349d00f1a3ade9544c2b117
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1xg84pwn/wheels/23/50/5b/3bd292280af53184d3c3f652258ad6173224b2281eef8c4d27
# Successfully built resnest
# Installing collected packages: resnest
# Successfully installed resnest-0.0.6b20200705

# %%
import os
import gc
import time
import shutil
import random
import warnings
import typing as tp
from pathlib import Path
from contextlib import contextmanager

import yaml
from joblib import delayed, Parallel

import cv2
import librosa
import audioread
import soundfile as sf

import numpy as np
import pandas as pd

from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data
import resnest.torch as resnest_torch

import pytorch_pfn_extras as ppe
from pytorch_pfn_extras.training import extensions as ppe_extensions

pd.options.display.max_rows = 500
pd.options.display.max_columns = 500

# %%
Path("/root/.cache/torch/checkpoints").mkdir(parents=True)

# %%
# !cp ../input/resnest50-fast-package/resnest50_fast_*.pth /root/.cache/torch/checkpoints/

# %% [markdown]
# ### define utilities

# %%
def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)  # type: ignore
#     torch.backends.cudnn.deterministic = True  # type: ignore
#     torch.backends.cudnn.benchmark = True  # type: ignore
    

@contextmanager
def timer(name: str) -> None:
    """Timer Util"""
    t0 = time.time()
    print("[{}] start".format(name))
    yield
    print("[{}] done in {:.0f} s".format(name, time.time() - t0))

# %% [markdown]
# ### read data

# %%
ROOT = Path.cwd().parent
INPUT_ROOT = ROOT / "input"
RAW_DATA = INPUT_ROOT / "birdsong-recognition"
TRAIN_AUDIO_DIR = RAW_DATA / "train_audio"
TRAIN_RESAMPLED_AUDIO_DIRS = [
  INPUT_ROOT / "birdsong-resampled-train-audio-{:0>2}".format(i)  for i in range(5)
]
TEST_AUDIO_DIR = RAW_DATA / "test_audio"

# %%
# train = pd.read_csv(RAW_DATA / "train.csv")
train = pd.read_csv(TRAIN_RESAMPLED_AUDIO_DIRS[0] / "train_mod.csv")

# %%
train.head().T
# Out:
#                                                                          0  \
# rating                                                                 3.5
# playback_used                                                           no
# ebird_code                                                          aldfly
# channels                                                          1 (mono)
# date                                                            2013-05-25
# pitch                                                        Not specified
# duration                                                                25
# filename                                                      XC134874.mp3
# speed                                                        Not specified
# species                                                   Alder Flycatcher
# number_of_notes                                              Not specified
# title                        XC134874 Alder Flycatcher (Empidonax alnorum)
# secondary_labels         ['Empidonax minimus_Least Flycatcher', 'Leioth...
# bird_seen                                                              yes
# sci_name                                                 Empidonax alnorum
# location                       Grey Cloud Dunes SNA, Washington, Minnesota
# latitude                                                            44.793
# sampling_rate                                                   48000 (Hz)
# type                                                                  call
# elevation                                                            220 m
# description              Two short segments of fairly quiet *pip* calls...
# bitrate_of_mp3                                                192000 (bps)
# file_type                                                              mp3
# volume                                                       Not specified
# background               American Yellow Warbler (Setophaga aestiva); L...
# xc_id                                                               134874
# url                                      https://www.xeno-canto.org/134874
# country                                                      United States
# author                                                    Jonathon Jongsma
# primary_label                           Empidonax alnorum_Alder Flycatcher
# longitude                                                          -92.962
# length                                                       Not specified
# time                                                                  8:00
# recordist                                                 Jonathon Jongsma
# license                        Creative Commons Attribution-ShareAlike 3.0
# resampled_sampling_rate                                              32000
# resampled_filename                                            XC134874.wav
# resampled_channels                                                1 (mono)
#
#                                                                          1  \
# rating                                                                   4
# playback_used                                                           no
# ebird_code                                                          aldfly
# channels                                                        2 (stereo)
# date                                                            2013-05-27
# pitch                                                                 both
# duration                                                                36
# filename                                                      XC135454.mp3
# speed                                                                 both
# species                                                   Alder Flycatcher
# number_of_notes                                                        1-3
# title                        XC135454 Alder Flycatcher (Empidonax alnorum)
# secondary_labels                                                        []
# bird_seen                                                              yes
# sci_name                                                 Empidonax alnorum
# location                  Carver's Gap Parking area, Roan Mountain Stat...
# latitude                                                           36.1065
# sampling_rate                                                   44100 (Hz)
# type                                                            call, song
# elevation                                                           1700 m
# description              At least three birds seen here moving around s...
# bitrate_of_mp3                                                128000 (bps)
# file_type                                                              mp3
# volume                                                               level
# background                                                             NaN
# xc_id                                                               135454
# url                                      https://www.xeno-canto.org/135454
# country                                                      United States
# author                                                         Mike Nelson
# primary_label                           Empidonax alnorum_Alder Flycatcher
# longitude                                                         -82.1106
# length                                                              0-3(s)
# time                                                                 08:30
# recordist                                                      Mike Nelson
# license                  Creative Commons Attribution-NonCommercial-Sha...
# resampled_sampling_rate                                              32000
# resampled_filename                                            XC135454.wav
# resampled_channels                                                1 (mono)
#
#                                                                          2  \
# rating                                                                   4
# playback_used                                                           no
# ebird_code                                                          aldfly
# channels                                                        2 (stereo)
# date                                                            2013-05-27
# pitch                                                                 both
# duration                                                                39
# filename                                                      XC135455.mp3
# speed                                                                 both
# species                                                   Alder Flycatcher
# number_of_notes                                                        1-3
# title                        XC135455 Alder Flycatcher (Empidonax alnorum)
# secondary_labels                                                        []
# bird_seen                                                              yes
# sci_name                                                 Empidonax alnorum
# location                  Carver's Gap Parking area, Roan Mountain Stat...
# latitude                                                           36.1065
# sampling_rate                                                   44100 (Hz)
# type                                                            call, song
# elevation                                                           1700 m
# description              At least three birds seen chasing each other a...
# bitrate_of_mp3                                                128000 (bps)
# file_type                                                              mp3
# volume                                                               level
# background                                                             NaN
# xc_id                                                               135455
# url                                      https://www.xeno-canto.org/135455
# country                                                      United States
# author                                                         Mike Nelson
# primary_label                           Empidonax alnorum_Alder Flycatcher
# longitude                                                         -82.1106
# length                                                              0-3(s)
# time                                                                 08:30
# recordist                                                      Mike Nelson
# license                  Creative Commons Attribution-NonCommercial-Sha...
# resampled_sampling_rate                                              32000
# resampled_filename                                            XC135455.wav
# resampled_channels                                                1 (mono)
#
#                                                                          3  \
# rating                                                                 3.5
# playback_used                                                           no
# ebird_code                                                          aldfly
# channels                                                        2 (stereo)
# date                                                            2013-05-27
# pitch                                                                 both
# duration                                                                33
# filename                                                      XC135456.mp3
# speed                                                                 both
# species                                                   Alder Flycatcher
# number_of_notes                                                        1-3
# title                        XC135456 Alder Flycatcher (Empidonax alnorum)
# secondary_labels         ['Dumetella carolinensis_Gray Catbird', 'Bomby...
# bird_seen                                                              yes
# sci_name                                                 Empidonax alnorum
# location                  Carver's Gap Parking area, Roan Mountain Stat...
# latitude                                                           36.1065
# sampling_rate                                                   44100 (Hz)
# type                                                            call, song
# elevation                                                           1700 m
# description              img:http://www.flickr.com/photos/madbirder/888...
# bitrate_of_mp3                                                128000 (bps)
# file_type                                                              mp3
# volume                                                               level
# background               Grey Catbird (Dumetella carolinensis); Cedar W...
# xc_id                                                               135456
# url                                      https://www.xeno-canto.org/135456
# country                                                      United States
# author                                                         Mike Nelson
# primary_label                           Empidonax alnorum_Alder Flycatcher
# longitude                                                         -82.1106
# length                                                              0-3(s)
# time                                                                 08:30
# recordist                                                      Mike Nelson
# license                  Creative Commons Attribution-NonCommercial-Sha...
# resampled_sampling_rate                                              32000
# resampled_filename                                            XC135456.wav
# resampled_channels                                                1 (mono)
#
#                                                                          4
# rating                                                                   4
# playback_used                                                           no
# ebird_code                                                          aldfly
# channels                                                        2 (stereo)
# date                                                            2013-05-27
# pitch                                                                 both
# duration                                                                36
# filename                                                      XC135457.mp3
# speed                                                                level
# species                                                   Alder Flycatcher
# number_of_notes                                                        1-3
# title                        XC135457 Alder Flycatcher (Empidonax alnorum)
# secondary_labels                                                        []
# bird_seen                                                              yes
# sci_name                                                 Empidonax alnorum
# location                  Carver's Gap Parking area, Roan Mountain Stat...
# latitude                                                           36.1065
# sampling_rate                                                   44100 (Hz)
# type                                                            call, song
# elevation                                                           1700 m
# description              img:http://www.flickr.com/photos/madbirder/888...
# bitrate_of_mp3                                                128000 (bps)
# file_type                                                              mp3
# volume                                                               level
# background                                                             NaN
# xc_id                                                               135457
# url                                      https://www.xeno-canto.org/135457
# country                                                      United States
# author                                                         Mike Nelson
# primary_label                           Empidonax alnorum_Alder Flycatcher
# longitude                                                         -82.1106
# length                                                              0-3(s)
# time                                                                 08:30
# recordist                                                      Mike Nelson
# license                  Creative Commons Attribution-NonCommercial-Sha...
# resampled_sampling_rate                                              32000
# resampled_filename                                            XC135457.wav
# resampled_channels                                                1 (mono)

# %%
if not TEST_AUDIO_DIR.exists():
    TEST_AUDIO_DIR = INPUT_ROOT / "birdcall-check" / "test_audio"
    test = pd.read_csv(INPUT_ROOT / "birdcall-check" / "test.csv")
else:
    test = pd.read_csv(RAW_DATA / "test.csv")

# %%
test.head().T
# Out:
#                                                   0  \
# site                                         site_1
# row_id    site_1_41e6fe6504a34bf6846938ba78d13df1_5
# seconds                                           5
# audio_id           41e6fe6504a34bf6846938ba78d13df1
#
#                                                    1  \
# site                                          site_1
# row_id    site_1_41e6fe6504a34bf6846938ba78d13df1_10
# seconds                                           10
# audio_id            41e6fe6504a34bf6846938ba78d13df1
#
#                                                    2  \
# site                                          site_1
# row_id    site_1_41e6fe6504a34bf6846938ba78d13df1_15
# seconds                                           15
# audio_id            41e6fe6504a34bf6846938ba78d13df1
#
#                                                    3  \
# site                                          site_1
# row_id    site_1_41e6fe6504a34bf6846938ba78d13df1_20
# seconds                                           20
# audio_id            41e6fe6504a34bf6846938ba78d13df1
#
#                                                    4
# site                                          site_1
# row_id    site_1_41e6fe6504a34bf6846938ba78d13df1_25
# seconds                                           25
# audio_id            41e6fe6504a34bf6846938ba78d13df1

# %% [markdown]
# ### settings

# %%
settings_str = """
globals:
  seed: 1213
  device: cuda
  num_epochs: 50
  output_dir: /kaggle/training_output/
  use_fold: 0
  target_sr: 32000

dataset:
  name: SpectrogramDataset
  params:
    img_size: 224
    melspectrogram_parameters:
      n_mels: 128
      fmin: 20
      fmax: 16000
    
split:
  name: StratifiedKFold
  params:
    n_splits: 5
    random_state: 42
    shuffle: True

loader:
  train:
    batch_size: 50
    shuffle: True
    num_workers: 2
    pin_memory: True
    drop_last: True
  val:
    batch_size: 100
    shuffle: False
    num_workers: 2
    pin_memory: True
    drop_last: False

model:
  name: resnest50_fast_1s1x64d
  params:
    pretrained: True
    n_classes: 264

loss:
  name: BCEWithLogitsLoss
  params: {}

optimizer:
  name: Adam
  params:
    lr: 0.001

scheduler:
  name: CosineAnnealingLR
  params:
    T_max: 10
"""

# %%
settings = yaml.safe_load(settings_str)

# %%
# if not torch.cuda.is_available():
#     settings["globals"]["device"] = "cpu"

# %%
for k, v in settings.items():
    print("[{}]".format(k))
    print(v)
# Out:
# [globals]
# {'seed': 1213, 'device': 'cuda', 'num_epochs': 50, 'output_dir': '/kaggle/training_output/', 'use_fold': 0, 'target_sr': 32000}
# [dataset]
# {'name': 'SpectrogramDataset', 'params': {'img_size': 224, 'melspectrogram_parameters': {'n_mels': 128, 'fmin': 20, 'fmax': 16000}}}
# [split]
# {'name': 'StratifiedKFold', 'params': {'n_splits': 5, 'random_state': 42, 'shuffle': True}}
# [loader]
# {'train': {'batch_size': 50, 'shuffle': True, 'num_workers': 2, 'pin_memory': True, 'drop_last': True}, 'val': {'batch_size': 100, 'shuffle': False, 'num_workers': 2, 'pin_memory': True, 'drop_last': False}}
# [model]
# {'name': 'resnest50_fast_1s1x64d', 'params': {'pretrained': True, 'n_classes': 264}}
# [loss]
# {'name': 'BCEWithLogitsLoss', 'params': {}}
# [optimizer]
# {'name': 'Adam', 'params': {'lr': 0.001}}
# [scheduler]
# {'name': 'CosineAnnealingLR', 'params': {'T_max': 10}}

# %% [markdown]
# ### preprocess audio data
#
# Code is forked from: https://github.com/koukyo1994/kaggle-birdcall-resnet-baseline-training/blob/master/input/birdsong-recognition/prepare.py
#
# I modified this partially.
#
# However, in this notebook, I used uploaded resampled audio because this preprocessing is too heavy for kaggle notebook.

# %%
def resample(ebird_code: str,filename: str, target_sr: int):    
    audio_dir = TRAIN_AUDIO_DIR
    resample_dir = TRAIN_RESAMPLED_DIR
    ebird_dir = resample_dir / ebird_code
    
    try:
        y, _ = librosa.load(
            audio_dir / ebird_code / filename,
            sr=target_sr, mono=True, res_type="kaiser_fast")

        filename = filename.replace(".mp3", ".wav")
        sf.write(ebird_dir / filename, y, samplerate=target_sr)
    except Exception as e:
        print(e)
        with open("skipped.txt", "a") as f:
            file_path = str(audio_dir / ebird_code / filename)
            f.write(file_path + "\n")

# %%
# train_org = train.copy()
# TRAIN_RESAMPLED_DIR = Path("/kaggle/processed_data/train_audio_resampled")
# TRAIN_RESAMPLED_DIR.mkdir(parents=True)

# for ebird_code in train.ebird_code.unique():
#     ebird_dir = TRAIN_RESAMPLED_DIR / ebird_code
#     ebird_dir.mkdir()

# warnings.simplefilter("ignore")
# train_audio_infos = train[["ebird_code", "filename"]].values.tolist()
# Parallel(n_jobs=NUM_THREAD, verbose=10)(
#     delayed(resample)(ebird_code, file_name, TARGET_SR) for ebird_code, file_name in train_audio_infos)

# train["resampled_sampling_rate"] = TARGET_SR
# train["resampled_filename"] = train["filename"].map(
#     lambda x: x.replace(".mp3", ".wav"))
# train["resampled_channels"] = "1 (mono)"

# %% [markdown]
# ## Definition

# %% [markdown]
# ### Dataset
# * forked from: https://github.com/koukyo1994/kaggle-birdcall-resnet-baseline-training/blob/master/src/dataset.py
# * modified partialy

# %%
BIRD_CODE = {
    'aldfly': 0, 'ameavo': 1, 'amebit': 2, 'amecro': 3, 'amegfi': 4,
    'amekes': 5, 'amepip': 6, 'amered': 7, 'amerob': 8, 'amewig': 9,
    'amewoo': 10, 'amtspa': 11, 'annhum': 12, 'astfly': 13, 'baisan': 14,
    'baleag': 15, 'balori': 16, 'banswa': 17, 'barswa': 18, 'bawwar': 19,
    'belkin1': 20, 'belspa2': 21, 'bewwre': 22, 'bkbcuc': 23, 'bkbmag1': 24,
    'bkbwar': 25, 'bkcchi': 26, 'bkchum': 27, 'bkhgro': 28, 'bkpwar': 29,
    'bktspa': 30, 'blkpho': 31, 'blugrb1': 32, 'blujay': 33, 'bnhcow': 34,
    'boboli': 35, 'bongul': 36, 'brdowl': 37, 'brebla': 38, 'brespa': 39,
    'brncre': 40, 'brnthr': 41, 'brthum': 42, 'brwhaw': 43, 'btbwar': 44,
    'btnwar': 45, 'btywar': 46, 'buffle': 47, 'buggna': 48, 'buhvir': 49,
    'bulori': 50, 'bushti': 51, 'buwtea': 52, 'buwwar': 53, 'cacwre': 54,
    'calgul': 55, 'calqua': 56, 'camwar': 57, 'cangoo': 58, 'canwar': 59,
    'canwre': 60, 'carwre': 61, 'casfin': 62, 'caster1': 63, 'casvir': 64,
    'cedwax': 65, 'chispa': 66, 'chiswi': 67, 'chswar': 68, 'chukar': 69,
    'clanut': 70, 'cliswa': 71, 'comgol': 72, 'comgra': 73, 'comloo': 74,
    'commer': 75, 'comnig': 76, 'comrav': 77, 'comred': 78, 'comter': 79,
    'comyel': 80, 'coohaw': 81, 'coshum': 82, 'cowscj1': 83, 'daejun': 84,
    'doccor': 85, 'dowwoo': 86, 'dusfly': 87, 'eargre': 88, 'easblu': 89,
    'easkin': 90, 'easmea': 91, 'easpho': 92, 'eastow': 93, 'eawpew': 94,
    'eucdov': 95, 'eursta': 96, 'evegro': 97, 'fiespa': 98, 'fiscro': 99,
    'foxspa': 100, 'gadwal': 101, 'gcrfin': 102, 'gnttow': 103, 'gnwtea': 104,
    'gockin': 105, 'gocspa': 106, 'goleag': 107, 'grbher3': 108, 'grcfly': 109,
    'greegr': 110, 'greroa': 111, 'greyel': 112, 'grhowl': 113, 'grnher': 114,
    'grtgra': 115, 'grycat': 116, 'gryfly': 117, 'haiwoo': 118, 'hamfly': 119,
    'hergul': 120, 'herthr': 121, 'hoomer': 122, 'hoowar': 123, 'horgre': 124,
    'horlar': 125, 'houfin': 126, 'houspa': 127, 'houwre': 128, 'indbun': 129,
    'juntit1': 130, 'killde': 131, 'labwoo': 132, 'larspa': 133, 'lazbun': 134,
    'leabit': 135, 'leafly': 136, 'leasan': 137, 'lecthr': 138, 'lesgol': 139,
    'lesnig': 140, 'lesyel': 141, 'lewwoo': 142, 'linspa': 143, 'lobcur': 144,
    'lobdow': 145, 'logshr': 146, 'lotduc': 147, 'louwat': 148, 'macwar': 149,
    'magwar': 150, 'mallar3': 151, 'marwre': 152, 'merlin': 153, 'moublu': 154,
    'mouchi': 155, 'moudov': 156, 'norcar': 157, 'norfli': 158, 'norhar2': 159,
    'normoc': 160, 'norpar': 161, 'norpin': 162, 'norsho': 163, 'norwat': 164,
    'nrwswa': 165, 'nutwoo': 166, 'olsfly': 167, 'orcwar': 168, 'osprey': 169,
    'ovenbi1': 170, 'palwar': 171, 'pasfly': 172, 'pecsan': 173, 'perfal': 174,
    'phaino': 175, 'pibgre': 176, 'pilwoo': 177, 'pingro': 178, 'pinjay': 179,
    'pinsis': 180, 'pinwar': 181, 'plsvir': 182, 'prawar': 183, 'purfin': 184,
    'pygnut': 185, 'rebmer': 186, 'rebnut': 187, 'rebsap': 188, 'rebwoo': 189,
    'redcro': 190, 'redhea': 191, 'reevir1': 192, 'renpha': 193, 'reshaw': 194,
    'rethaw': 195, 'rewbla': 196, 'ribgul': 197, 'rinduc': 198, 'robgro': 199,
    'rocpig': 200, 'rocwre': 201, 'rthhum': 202, 'ruckin': 203, 'rudduc': 204,
    'rufgro': 205, 'rufhum': 206, 'rusbla': 207, 'sagspa1': 208, 'sagthr': 209,
    'savspa': 210, 'saypho': 211, 'scatan': 212, 'scoori': 213, 'semplo': 214,
    'semsan': 215, 'sheowl': 216, 'shshaw': 217, 'snobun': 218, 'snogoo': 219,
    'solsan': 220, 'sonspa': 221, 'sora': 222, 'sposan': 223, 'spotow': 224,
    'stejay': 225, 'swahaw': 226, 'swaspa': 227, 'swathr': 228, 'treswa': 229,
    'truswa': 230, 'tuftit': 231, 'tunswa': 232, 'veery': 233, 'vesspa': 234,
    'vigswa': 235, 'warvir': 236, 'wesblu': 237, 'wesgre': 238, 'weskin': 239,
    'wesmea': 240, 'wessan': 241, 'westan': 242, 'wewpew': 243, 'whbnut': 244,
    'whcspa': 245, 'whfibi': 246, 'whtspa': 247, 'whtswi': 248, 'wilfly': 249,
    'wilsni1': 250, 'wiltur': 251, 'winwre3': 252, 'wlswar': 253, 'wooduc': 254,
    'wooscj2': 255, 'woothr': 256, 'y00475': 257, 'yebfly': 258, 'yebsap': 259,
    'yehbla': 260, 'yelwar': 261, 'yerwar': 262, 'yetvir': 263
}

INV_BIRD_CODE = {v: k for k, v in BIRD_CODE.items()}

# %%
PERIOD = 5

def mono_to_color(
    X: np.ndarray, mean=None, std=None,
    norm_max=None, norm_min=None, eps=1e-6
):
    # Stack X as [X,X,X]
    X = np.stack([X, X, X], axis=-1)

    # Standardize
    mean = mean or X.mean()
    X = X - mean
    std = std or X.std()
    Xstd = X / (std + eps)
    _min, _max = Xstd.min(), Xstd.max()
    norm_max = norm_max or _max
    norm_min = norm_min or _min
    if (_max - _min) > eps:
        # Normalize to [0, 255]
        V = Xstd
        V[V < norm_min] = norm_min
        V[V > norm_max] = norm_max
        V = 255 * (V - norm_min) / (norm_max - norm_min)
        V = V.astype(np.uint8)
    else:
        # Just zero
        V = np.zeros_like(Xstd, dtype=np.uint8)
    return V

class SpectrogramDataset(data.Dataset):
    def __init__(
        self,
        file_list: tp.List[tp.List[str]], img_size=224,
        waveform_transforms=None, spectrogram_transforms=None, melspectrogram_parameters={}
    ):
        self.file_list = file_list  # list of list: [file_path, ebird_code]
        self.img_size = img_size
        self.waveform_transforms = waveform_transforms
        self.spectrogram_transforms = spectrogram_transforms
        self.melspectrogram_parameters = melspectrogram_parameters

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx: int):
        wav_path, ebird_code = self.file_list[idx]

        y, sr = sf.read(wav_path)

        if self.waveform_transforms:
            y = self.waveform_transforms(y)
        else:
            len_y = len(y)
            effective_length = sr * PERIOD
            if len_y < effective_length:
                new_y = np.zeros(effective_length, dtype=y.dtype)
                start = np.random.randint(effective_length - len_y)
                new_y[start:start + len_y] = y
                y = new_y.astype(np.float32)
            elif len_y > effective_length:
                start = np.random.randint(len_y - effective_length)
                y = y[start:start + effective_length].astype(np.float32)
            else:
                y = y.astype(np.float32)

        melspec = librosa.feature.melspectrogram(y, sr=sr, **self.melspectrogram_parameters)
        melspec = librosa.power_to_db(melspec).astype(np.float32)

        if self.spectrogram_transforms:
            melspec = self.spectrogram_transforms(melspec)
        else:
            pass

        image = mono_to_color(melspec)
        height, width, _ = image.shape
        image = cv2.resize(image, (int(width * self.img_size / height), self.img_size))
        image = np.moveaxis(image, 2, 0)
        image = (image / 255.0).astype(np.float32)

#         labels = np.zeros(len(BIRD_CODE), dtype="i")
        labels = np.zeros(len(BIRD_CODE), dtype="f")
        labels[BIRD_CODE[ebird_code]] = 1

        return image, labels

# %% [markdown]
# ### Training Utility

# %%
def get_loaders_for_training(
    args_dataset: tp.Dict, args_loader: tp.Dict,
    train_file_list: tp.List[str], val_file_list: tp.List[str]
):
    # # make dataset
    train_dataset = SpectrogramDataset(train_file_list, **args_dataset)
    val_dataset = SpectrogramDataset(val_file_list, **args_dataset)
    # # make dataloader
    train_loader = data.DataLoader(train_dataset, **args_loader["train"])
    val_loader = data.DataLoader(val_dataset, **args_loader["val"])
    
    return train_loader, val_loader

# %%
def get_model(args: tp.Dict):
    model =getattr(resnest_torch, args["name"])(pretrained=args["params"]["pretrained"])
    del model.fc
    # # use the same head as the baseline notebook.
    model.fc = nn.Sequential(
        nn.Linear(2048, 1024), nn.ReLU(), nn.Dropout(p=0.2),
        nn.Linear(1024, 1024), nn.ReLU(), nn.Dropout(p=0.2),
        nn.Linear(1024, args["params"]["n_classes"]))
    
    return model

# %%
def train_loop(
    manager, args, model, device,
    train_loader, optimizer, scheduler, loss_func
):
    """Run minibatch training loop"""
    while not manager.stop_trigger:
        model.train()
        for batch_idx, (data, target) in enumerate(train_loader):
            with manager.run_iteration():
                data, target = data.to(device), target.to(device)
                optimizer.zero_grad()
                output = model(data)
                loss = loss_func(output, target)
                ppe.reporting.report({'train/loss': loss.item()})
                loss.backward()
                optimizer.step()
                scheduler.step()

def eval_for_batch(
    args, model, device,
    data, target, loss_func, eval_func_dict={}
):
    """
    Run evaliation for valid
    
    This function is applied to each batch of val loader.
    """
    model.eval()
    data, target = data.to(device), target.to(device)
    output = model(data)
    # Final result will be average of averages of the same size
    val_loss = loss_func(output, target).item()
    ppe.reporting.report({'val/loss': val_loss})
    
    for eval_name, eval_func in eval_func_dict.items():
        eval_value = eval_func(output, target).item()
        ppe.reporting.report({"val/{}".format(eval_aame): eval_value})

# %%
def set_extensions(
    manager, args, model, device, test_loader, optimizer,
    loss_func, eval_func_dict={}
):
    """set extensions for PPE"""
        
    my_extensions = [
        # # observe, report
        ppe_extensions.observe_lr(optimizer=optimizer),
        # ppe_extensions.ParameterStatistics(model, prefix='model'),
        # ppe_extensions.VariableStatisticsPlot(model),
        ppe_extensions.LogReport(),
        ppe_extensions.PlotReport(['train/loss', 'val/loss'], 'epoch', filename='loss.png'),
        ppe_extensions.PlotReport(['lr',], 'epoch', filename='lr.png'),
        ppe_extensions.PrintReport([
            'epoch', 'iteration', 'lr', 'train/loss', 'val/loss', "elapsed_time"]),
#         ppe_extensions.ProgressBar(update_interval=100),

        # # evaluation
        (
            ppe_extensions.Evaluator(
                test_loader, model,
                eval_func=lambda data, target:
                    eval_for_batch(args, model, device, data, target, loss_func, eval_func_dict),
                progress_bar=True),
            (1, "epoch"),
        ),
        # # save model snapshot.
        (
            ppe_extensions.snapshot(
                target=model, filename="snapshot_epoch_{.updater.epoch}.pth"),
            ppe.training.triggers.MinValueTrigger(key="val/loss", trigger=(1, 'epoch'))
        ),
    ]
           
    # # set extensions to manager
    for ext in my_extensions:
        if isinstance(ext, tuple):
            manager.extend(ext[0], trigger=ext[1])
        else:
            manager.extend(ext)
        
    return manager

# %% [markdown]
# ## Training

# %% [markdown]
# ### prepare data

# %% [markdown]
# #### get wav file path

# %%
tmp_list = []
for audio_d in TRAIN_RESAMPLED_AUDIO_DIRS:
    if not audio_d.exists():
        continue
    for ebird_d in audio_d.iterdir():
        if ebird_d.is_file():
            continue
        for wav_f in ebird_d.iterdir():
            tmp_list.append([ebird_d.name, wav_f.name, wav_f.as_posix()])
            
train_wav_path_exist = pd.DataFrame(
    tmp_list, columns=["ebird_code", "resampled_filename", "file_path"])

del tmp_list

train_all = pd.merge(
    train, train_wav_path_exist, on=["ebird_code", "resampled_filename"], how="inner")

print(train.shape)
print(train_wav_path_exist.shape)
print(train_all.shape)
# Out:
# (21375, 38)
# (21375, 3)
# (21375, 39)

# %%
train_all.head()
# Out:
#    rating playback_used ebird_code    channels        date          pitch  \
# 0     3.5            no     aldfly    1 (mono)  2013-05-25  Not specified
# 1     4.0            no     aldfly  2 (stereo)  2013-05-27           both
# 2     4.0            no     aldfly  2 (stereo)  2013-05-27           both
# 3     3.5            no     aldfly  2 (stereo)  2013-05-27           both
# 4     4.0            no     aldfly  2 (stereo)  2013-05-27           both
#
#    duration      filename          speed           species number_of_notes  \
# 0        25  XC134874.mp3  Not specified  Alder Flycatcher   Not specified
# 1        36  XC135454.mp3           both  Alder Flycatcher             1-3
# 2        39  XC135455.mp3           both  Alder Flycatcher             1-3
# 3        33  XC135456.mp3           both  Alder Flycatcher             1-3
# 4        36  XC135457.mp3          level  Alder Flycatcher             1-3
#
#                                            title  \
# 0  XC134874 Alder Flycatcher (Empidonax alnorum)
# 1  XC135454 Alder Flycatcher (Empidonax alnorum)
# 2  XC135455 Alder Flycatcher (Empidonax alnorum)
# 3  XC135456 Alder Flycatcher (Empidonax alnorum)
# 4  XC135457 Alder Flycatcher (Empidonax alnorum)
#
#                                     secondary_labels bird_seen  \
# 0  ['Empidonax minimus_Least Flycatcher', 'Leioth...       yes
# 1                                                 []       yes
# 2                                                 []       yes
# 3  ['Dumetella carolinensis_Gray Catbird', 'Bomby...       yes
# 4                                                 []       yes
#
#             sci_name                                           location  \
# 0  Empidonax alnorum        Grey Cloud Dunes SNA, Washington, Minnesota
# 1  Empidonax alnorum   Carver's Gap Parking area, Roan Mountain Stat...
# 2  Empidonax alnorum   Carver's Gap Parking area, Roan Mountain Stat...
# 3  Empidonax alnorum   Carver's Gap Parking area, Roan Mountain Stat...
# 4  Empidonax alnorum   Carver's Gap Parking area, Roan Mountain Stat...
#
#   latitude sampling_rate        type elevation  \
# 0   44.793    48000 (Hz)        call     220 m
# 1  36.1065    44100 (Hz)  call, song    1700 m
# 2  36.1065    44100 (Hz)  call, song    1700 m
# 3  36.1065    44100 (Hz)  call, song    1700 m
# 4  36.1065    44100 (Hz)  call, song    1700 m
#
#                                          description bitrate_of_mp3 file_type  \
# 0  Two short segments of fairly quiet *pip* calls...   192000 (bps)       mp3
# 1  At least three birds seen here moving around s...   128000 (bps)       mp3
# 2  At least three birds seen chasing each other a...   128000 (bps)       mp3
# 3  img:http://www.flickr.com/photos/madbirder/888...   128000 (bps)       mp3
# 4  img:http://www.flickr.com/photos/madbirder/888...   128000 (bps)       mp3
#
#           volume                                         background   xc_id  \
# 0  Not specified  American Yellow Warbler (Setophaga aestiva); L...  134874
# 1          level                                                NaN  135454
# 2          level                                                NaN  135455
# 3          level  Grey Catbird (Dumetella carolinensis); Cedar W...  135456
# 4          level                                                NaN  135457
#
#                                  url        country            author  \
# 0  https://www.xeno-canto.org/134874  United States  Jonathon Jongsma
# 1  https://www.xeno-canto.org/135454  United States       Mike Nelson
# 2  https://www.xeno-canto.org/135455  United States       Mike Nelson
# 3  https://www.xeno-canto.org/135456  United States       Mike Nelson
# 4  https://www.xeno-canto.org/135457  United States       Mike Nelson
#
#                         primary_label longitude         length   time  \
# 0  Empidonax alnorum_Alder Flycatcher   -92.962  Not specified   8:00
# 1  Empidonax alnorum_Alder Flycatcher  -82.1106         0-3(s)  08:30
# 2  Empidonax alnorum_Alder Flycatcher  -82.1106         0-3(s)  08:30
# 3  Empidonax alnorum_Alder Flycatcher  -82.1106         0-3(s)  08:30
# 4  Empidonax alnorum_Alder Flycatcher  -82.1106         0-3(s)  08:30
#
#           recordist                                            license  \
# 0  Jonathon Jongsma        Creative Commons Attribution-ShareAlike 3.0
# 1       Mike Nelson  Creative Commons Attribution-NonCommercial-Sha...
# 2       Mike Nelson  Creative Commons Attribution-NonCommercial-Sha...
# 3       Mike Nelson  Creative Commons Attribution-NonCommercial-Sha...
# 4       Mike Nelson  Creative Commons Attribution-NonCommercial-Sha...
#
#    resampled_sampling_rate resampled_filename resampled_channels  \
# 0                    32000       XC134874.wav           1 (mono)
# 1                    32000       XC135454.wav           1 (mono)
# 2                    32000       XC135455.wav           1 (mono)
# 3                    32000       XC135456.wav           1 (mono)
# 4                    32000       XC135457.wav           1 (mono)
#
#                                            file_path
# 0  /kaggle/input/birdsong-resampled-train-audio-0...
# 1  /kaggle/input/birdsong-resampled-train-audio-0...
# 2  /kaggle/input/birdsong-resampled-train-audio-0...
# 3  /kaggle/input/birdsong-resampled-train-audio-0...
# 4  /kaggle/input/birdsong-resampled-train-audio-0...

# %% [markdown]
# #### split data

# %%
# # for test run
# test_run_idx = sorted(np.random.choice(len(train_all), len(train_all) // 10, replace=False))
# train_all = train_all.iloc[test_run_idx, :].reset_index(drop=True)
# settings["globals"]["num_epochs"] = 20
# settings["scheduler"]["params"]["T_max"] = 4

# %%
skf = StratifiedKFold(**settings["split"]["params"])

train_all["fold"] = -1
for fold_id, (train_index, val_index) in enumerate(skf.split(train_all, train_all["ebird_code"])):
    train_all.iloc[val_index, -1] = fold_id
    
# # check the propotion
fold_proportion = pd.pivot_table(train_all, index="ebird_code", columns="fold", values="xc_id", aggfunc=len)
print(fold_proportion.shape)
# Out:
# (264, 5)

# %%
fold_proportion
# Out:
# fold         0   1   2   3   4
# ebird_code
# aldfly      20  20  20  20  20
# ameavo       8   8   8   7   7
# amebit       9   9   8   9   9
# amecro      20  20  20  20  20
# amegfi      20  20  20  20  20
# amekes      15  15  15  15  15
# amepip      20  20  20  20  20
# amered      20  20  20  20  20
# amerob      20  20  20  20  20
# amewig       6   6   7   7   7
# amewoo      17  17  17  16  16
# amtspa      15  15  14  15  15
# annhum      20  20  20  20  20
# astfly      20  20  20  20  20
# baisan      11  11  11  11  11
# baleag       7   7   7   7   7
# balori      20  20  20  20  20
# banswa      20  20  20  20  20
# barswa      20  20  20  20  20
# bawwar      15  14  15  15  15
# belkin1     13  14  14  14  14
# belspa2     16  15  15  15  15
# bewwre      20  20  20  20  20
# bkbcuc       9  10  10  10   9
# bkbmag1     12  12  12  12  12
# bkbwar      20  20  20  20  20
# bkcchi      20  20  20  20  20
# bkchum      14  14  13  13  14
# bkhgro      20  20  20  20  20
# bkpwar      20  20  20  20  20
# bktspa      19  18  19  19  19
# blkpho      20  20  20  20  20
# blugrb1     20  20  20  20  20
# blujay      20  20  20  20  20
# bnhcow      20  20  20  20  20
# boboli      20  20  20  20  20
# bongul       8   8   8   8   8
# brdowl      20  20  20  20  20
# brebla       9  10  10  10  10
# brespa      20  20  20  20  20
# brncre      20  20  20  20  20
# brnthr      20  20  20  20  20
# brthum      20  20  20  20  19
# brwhaw      15  15  15  14  15
# btbwar      15  15  15  15  15
# btnwar      20  20  20  20  20
# btywar      19  19  19  20  19
# buffle       3   3   3   3   3
# buggna      20  20  20  20  20
# buhvir      20  20  20  20  20
# bulori      20  20  20  20  20
# bushti      20  20  20  20  20
# buwtea      11  11  10  10  11
# buwwar      19  19  20  20  19
# cacwre      20  20  20  20  20
# calgul       8   8   8   8   8
# calqua      18  18  18  18  18
# camwar      15  15  15  15  16
# cangoo      20  20  20  20  20
# canwar      20  20  20  20  20
# canwre      20  20  20  20  20
# carwre      20  20  20  20  20
# casfin      16  15  15  15  15
# caster1     20  20  20  20  20
# casvir      18  18  18  18  18
# cedwax      17  18  18  18  18
# chispa      20  20  20  20  20
# chiswi       6   6   6   6   5
# chswar      20  20  20  20  20
# chukar       6   6   6   6   6
# clanut      16  16  16  15  16
# cliswa      13  13  13  13  13
# comgol      17  17  17  18  18
# comgra      20  20  20  20  20
# comloo      14  13  13  13  13
# commer      16  17  17  16  16
# comnig      17  17  17  18  17
# comrav      20  20  20  20  20
# comred      20  20  20  20  20
# comter      20  20  20  20  20
# comyel      20  20  20  20  20
# coohaw      18  18  18  18  18
# coshum       4   4   4   3   4
# cowscj1     14  14  13  14  14
# daejun      20  20  20  20  20
# doccor       7   6   7   7   7
# dowwoo      20  20  20  20  20
# dusfly      19  20  20  20  19
# eargre       8   7   7   7   8
# easblu      19  20  19  19  19
# easkin      16  16  17  17  16
# easmea      20  20  20  20  20
# easpho      18  18  18  18  19
# eastow      20  20  20  20  20
# eawpew      20  20  20  20  20
# eucdov      20  20  20  20  20
# eursta       8   8   8   8   8
# evegro      20  20  20  20  20
# fiespa      20  20  20  20  20
# fiscro      18  18  17  17  17
# foxspa      20  20  20  20  20
# gadwal      20  20  20  20  20
# gcrfin       6   6   7   6   6
# gnttow      20  20  20  20  20
# gnwtea      20  20  20  20  20
# gockin      20  20  20  20  20
# gocspa      14  14  14  14  14
# goleag      10  10  10  10  10
# grbher3     14  14  14  15  15
# grcfly      20  20  20  20  20
# greegr      20  20  20  20  20
# greroa      18  18  18  18  18
# greyel      20  20  20  20  20
# grhowl      20  20  20  20  20
# grnher      14  13  13  13  13
# grtgra      20  20  20  20  20
# grycat      16  17  17  16  16
# gryfly      16  16  16  17  16
# haiwoo      20  20  20  20  20
# hamfly      20  20  20  20  20
# hergul      20  20  20  20  20
# herthr      20  20  20  20  20
# hoomer       4   4   4   3   4
# hoowar      20  20  20  20  20
# horgre      13  13  13  14  14
# horlar      20  20  20  20  20
# houfin      20  20  20  20  20
# houspa      20  20  20  20  20
# houwre      20  20  20  20  20
# indbun      20  20  20  20  20
# juntit1     14  14  14  14  13
# killde      20  20  20  20  20
# labwoo      17  17  17  17  17
# larspa      19  19  19  19  19
# lazbun      20  19  19  19  20
# leabit      18  19  18  18  18
# leafly      19  19  19  19  19
# leasan      15  14  15  15  15
# lecthr       4   4   4   4   4
# lesgol      20  20  20  20  20
# lesnig       8   9   9   8   8
# lesyel      20  20  20  20  20
# lewwoo       6   5   5   6   6
# linspa      20  20  20  20  20
# lobcur      13  14  13  13  13
# lobdow      15  15  15  15  15
# logshr      20  20  20  20  20
# lotduc      12  12  12  12  12
# louwat      20  20  20  20  20
# macwar      20  20  20  20  20
# magwar      20  20  20  20  20
# mallar3     20  20  20  20  20
# marwre      20  20  20  20  20
# merlin      11  11  12  12  11
# moublu       6   6   6   6   6
# mouchi      20  20  20  20  20
# moudov      20  20  20  20  20
# norcar      20  20  20  20  20
# norfli      20  20  20  20  20
# norhar2      6   6   6   5   6
# normoc      20  20  20  20  20
# norpar      20  20  20  20  20
# norpin       8   8   7   8   8
# norsho      13  13  13  13  13
# norwat      20  20  20  20  20
# nrwswa       6   6   6   6   6
# nutwoo       9   8   9   9   9
# olsfly      20  20  20  20  20
# orcwar      20  20  20  20  20
# osprey      20  20  20  20  20
# ovenbi1     20  20  20  20  20
# palwar       9  10   9   9   9
# pasfly      20  20  20  20  20
# pecsan      13  13  14  13  13
# perfal      20  20  20  20  20
# phaino      12  12  12  12  12
# pibgre      20  20  20  20  20
# pilwoo      20  20  20  20  20
# pingro      19  18  18  19  19
# pinjay      10  11  10  10  10
# pinsis      20  20  20  20  20
# pinwar      20  20  20  20  20
# plsvir      18  18  19  19  18
# prawar      14  14  14  14  14
# purfin      20  20  20  20  20
# pygnut      12  12  12  12  12
# rebmer       6   6   6   5   6
# rebnut      20  20  20  20  20
# rebsap       6   6   6   7   7
# rebwoo      20  20  20  20  20
# redcro      20  20  20  20  20
# redhea       2   2   2   2   1
# reevir1     20  20  20  20  20
# renpha      15  15  15  14  15
# reshaw      15  14  14  15  15
# rethaw      18  19  19  19  18
# rewbla      20  20  20  20  20
# ribgul      13  13  13  13  14
# rinduc       5   5   5   5   5
# robgro      20  20  20  20  20
# rocpig      20  20  20  20  20
# rocwre      16  16  16  15  15
# rthhum       6   6   6   7   6
# ruckin      20  20  20  20  20
# rudduc       5   5   4   4   5
# rufgro       5   4   5   5   5
# rufhum      11  12  12  12  12
# rusbla      12  12  11  11  11
# sagspa1      6   6   6   6   6
# sagthr       7   7   7   7   7
# savspa      20  20  20  20  20
# saypho      11  11  11  11  11
# scatan      19  18  19  19  19
# scoori      20  20  20  20  20
# semplo      12  13  13  13  13
# semsan      14  14  14  14  14
# sheowl      12  12  11  11  11
# shshaw       4   4   5   5   4
# snobun      20  20  20  20  20
# snogoo      16  15  15  15  16
# solsan      18  19  19  19  19
# sonspa      20  20  20  20  20
# sora        20  20  20  20  20
# sposan      19  19  19  18  18
# spotow      20  20  20  20  20
# stejay      20  20  20  20  20
# swahaw       5   5   5   6   5
# swaspa      20  20  20  20  20
# swathr      20  20  20  20  20
# treswa      17  17  17  17  17
# truswa       8   8   7   7   8
# tuftit      20  20  20  20  20
# tunswa      13  12  13  13  13
# veery       20  20  20  20  20
# vesspa      20  20  20  20  20
# vigswa      10  11  11  10  10
# warvir      20  20  20  20  20
# wesblu       7   7   7   7   7
# wesgre       8   7   7   8   8
# weskin      16  17  17  17  16
# wesmea      20  20  20  20  20
# wessan       6   6   6   6   6
# westan      20  20  20  20  20
# wewpew      20  20  20  20  20
# whbnut      20  20  20  20  20
# whcspa      20  20  20  20  20
# whfibi       7   7   6   6   7
# whtspa      20  20  20  20  20
# whtswi       7   7   8   7   7
# wilfly      20  20  20  20  20
# wilsni1     20  20  20  20  20
# wiltur       9   9   9  10   9
# winwre3     20  20  20  20  20
# wlswar      20  20  20  20  20
# wooduc       8   8   8   8   8
# wooscj2     18  18  18  17  18
# woothr      20  20  20  20  20
# y00475      20  20  20  20  20
# yebfly      20  20  20  20  20
# yebsap      13  12  12  13  13
# yehbla      11  12  12  11  11
# yelwar      18  18  17  18  18
# yerwar      20  20  20  20  20
# yetvir      19  19  20  20  20

# %%
use_fold = settings["globals"]["use_fold"]
train_file_list = train_all.query("fold != @use_fold")[["file_path", "ebird_code"]].values.tolist()
val_file_list = train_all.query("fold == @use_fold")[["file_path", "ebird_code"]].values.tolist()

print("[fold {}] train: {}, val: {}".format(use_fold, len(train_file_list), len(val_file_list)))
# Out:
# [fold 0] train: 17100, val: 4275

# %% [markdown]
# ## run training

# %%
set_seed(settings["globals"]["seed"])
device = torch.device(settings["globals"]["device"])
output_dir = Path(settings["globals"]["output_dir"])

# # # get loader
train_loader, val_loader = get_loaders_for_training(
    settings["dataset"]["params"], settings["loader"], train_file_list, val_file_list)

# # # get model
model = get_model(settings["model"])
model = model.to(device)

# # # get optimizer
optimizer = getattr(
    torch.optim, settings["optimizer"]["name"]
)(model.parameters(), **settings["optimizer"]["params"])

# # # get scheduler
scheduler = getattr(
    torch.optim.lr_scheduler, settings["scheduler"]["name"]
)(optimizer, **settings["scheduler"]["params"])

# # # get loss
loss_func = getattr(nn, settings["loss"]["name"])(**settings["loss"]["params"])

# # # create training manager
trigger = None

manager = ppe.training.ExtensionsManager(
    model, optimizer, settings["globals"]["num_epochs"],
    iters_per_epoch=len(train_loader),
    stop_trigger=trigger,
    out_dir=output_dir
)

# # # set manager extensions
manager = set_extensions(
    manager, settings, model, device,
    val_loader, optimizer, loss_func,
)

# %%
# # runtraining
train_loop(
    manager, settings, model, device,
    train_loader, optimizer, scheduler, loss_func)
# Out:
# epoch       iteration   lr          train/loss  val/loss    elapsed_time
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#.................................................]  2.33%
#          1 iterations
#     2.4767 iters/sec. Estimated time to finish: 0:00:16.957728.
# validation [##................................................]  4.65%
#          2 iterations
#    0.42871 iters/sec. Estimated time to finish: 0:01:35.634840.
# validation [###...............................................]  6.98%
#          3 iterations
#    0.59186 iters/sec. Estimated time to finish: 0:01:07.583758.
# validation [####..............................................]  9.30%
#          4 iterations
#    0.45672 iters/sec. Estimated time to finish: 0:01:25.392298.
# validation [#####.............................................] 11.63%
#          5 iterations
#    0.54597 iters/sec. Estimated time to finish: 0:01:09.600967.
# validation [######............................................] 13.95%
#          6 iterations
#    0.42901 iters/sec. Estimated time to finish: 0:01:26.244689.
# validation [########..........................................] 16.28%
#          7 iterations
#     0.4867 iters/sec. Estimated time to finish: 0:01:13.967490.
# validation [#########.........................................] 18.60%
#          8 iterations
#    0.42356 iters/sec. Estimated time to finish: 0:01:22.631995.
# validation [##########........................................] 20.93%
#          9 iterations
#    0.46636 iters/sec. Estimated time to finish: 0:01:12.905395.
# validation [###########.......................................] 23.26%
#         10 iterations
#     0.4125 iters/sec. Estimated time to finish: 0:01:20.000012.
# validation [############......................................] 25.58%
#         11 iterations
#     0.4464 iters/sec. Estimated time to finish: 0:01:11.684733.
# validation [#############.....................................] 27.91%
#         12 iterations
#    0.39702 iters/sec. Estimated time to finish: 0:01:18.082644.
# validation [###############...................................] 30.23%
#         13 iterations
#    0.42452 iters/sec. Estimated time to finish: 0:01:10.667244.
# validation [################..................................] 32.56%
#         14 iterations
#    0.35043 iters/sec. Estimated time to finish: 0:01:22.755788.
# validation [#################.................................] 34.88%
#         15 iterations
#    0.37168 iters/sec. Estimated time to finish: 0:01:15.333094.
# validation [##################................................] 37.21%
#         16 iterations
#    0.36032 iters/sec. Estimated time to finish: 0:01:14.933028.
# validation [###################...............................] 39.53%
#         17 iterations
#     0.3793 iters/sec. Estimated time to finish: 0:01:08.547541.
# validation [####################..............................] 41.86%
#         18 iterations
#     0.3277 iters/sec. Estimated time to finish: 0:01:16.288766.
# validation [######################............................] 44.19%
#         19 iterations
#    0.34342 iters/sec. Estimated time to finish: 0:01:09.884339.
# validation [#######################...........................] 46.51%
#         20 iterations
#    0.29868 iters/sec. Estimated time to finish: 0:01:17.005556.
# validation [########################..........................] 48.84%
#         21 iterations
#    0.31176 iters/sec. Estimated time to finish: 0:01:10.568225.
# validation [#########################.........................] 51.16%
#         22 iterations
#    0.30597 iters/sec. Estimated time to finish: 0:01:08.633109.
# validation [##########################........................] 53.49%
#         23 iterations
#    0.31813 iters/sec. Estimated time to finish: 0:01:02.868082.
# validation [###########################.......................] 55.81%
#         24 iterations
#    0.31397 iters/sec. Estimated time to finish: 0:01:00.516231.
# validation [#############################.....................] 58.14%
#         25 iterations
#    0.32531 iters/sec. Estimated time to finish: 0:00:55.331862.
# validation [##############################....................] 60.47%
#         26 iterations
#    0.31911 iters/sec. Estimated time to finish: 0:00:53.273507.
# validation [###############################...................] 62.79%
#         27 iterations
#    0.32974 iters/sec. Estimated time to finish: 0:00:48.523073.
# validation [################################..................] 65.12%
#         28 iterations
#    0.32411 iters/sec. Estimated time to finish: 0:00:46.280473.
# validation [#################################.................] 67.44%
#         29 iterations
#    0.33414 iters/sec. Estimated time to finish: 0:00:41.898484.
# validation [##################################................] 69.77%
#         30 iterations
#    0.32757 iters/sec. Estimated time to finish: 0:00:39.685986.
# validation [####################################..............] 72.09%
#         31 iterations
#    0.33701 iters/sec. Estimated time to finish: 0:00:35.606964.
# validation [#####################################.............] 74.42%
#         32 iterations
#    0.33161 iters/sec. Estimated time to finish: 0:00:33.171519.
# validation [######################################............] 76.74%
#         33 iterations
#    0.34055 iters/sec. Estimated time to finish: 0:00:29.364130.
# validation [#######################################...........] 79.07%
#         34 iterations
#    0.33424 iters/sec. Estimated time to finish: 0:00:26.926947.
# validation [########################################..........] 81.40%
#         35 iterations
#    0.34269 iters/sec. Estimated time to finish: 0:00:23.344655.
# validation [#########################################.........] 83.72%
#         36 iterations
#    0.33854 iters/sec. Estimated time to finish: 0:00:20.676802.
# validation [###########################################.......] 86.05%
#         37 iterations
#    0.34663 iters/sec. Estimated time to finish: 0:00:17.309393.
# validation [############################################......] 88.37%
#         38 iterations
#    0.34103 iters/sec. Estimated time to finish: 0:00:14.661492.
# validation [#############################################.....] 90.70%
#         39 iterations
#    0.34872 iters/sec. Estimated time to finish: 0:00:11.470480.
# validation [##############################################....] 93.02%
#         40 iterations
#    0.34722 iters/sec. Estimated time to finish: 0:00:08.639932.
# validation [###############################################...] 95.35%
#         41 iterations
#    0.35468 iters/sec. Estimated time to finish: 0:00:05.638892.
# validation [################################################..] 97.67%
#         42 iterations
#    0.35732 iters/sec. Estimated time to finish: 0:00:02.798645.
# 1           342         0.000904508  0.0312487   0.0248256   569.17
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#.................................................]  2.33%
#          1 iterations
#     2.4606 iters/sec. Estimated time to finish: 0:00:17.068849.
# validation [##................................................]  4.65%
#          2 iterations
#    0.40447 iters/sec. Estimated time to finish: 0:01:41.366037.
# validation [###...............................................]  6.98%
#          3 iterations
#    0.56119 iters/sec. Estimated time to finish: 0:01:11.277335.
# validation [####..............................................]  9.30%
#          4 iterations
#    0.41914 iters/sec. Estimated time to finish: 0:01:33.047527.
# validation [#####.............................................] 11.63%
#          5 iterations
#    0.50273 iters/sec. Estimated time to finish: 0:01:15.587020.
# validation [######............................................] 13.95%
#          6 iterations
#    0.41386 iters/sec. Estimated time to finish: 0:01:29.402799.
# validation [########..........................................] 16.28%
#          7 iterations
#    0.46936 iters/sec. Estimated time to finish: 0:01:16.700420.
# validation [#########.........................................] 18.60%
#          8 iterations
#    0.41446 iters/sec. Estimated time to finish: 0:01:24.446926.
# validation [##########........................................] 20.93%
#          9 iterations
#    0.45662 iters/sec. Estimated time to finish: 0:01:14.460584.
# validation [###########.......................................] 23.26%
#         10 iterations
#    0.41606 iters/sec. Estimated time to finish: 0:01:19.315021.
# validation [############......................................] 25.58%
#         11 iterations
#    0.45017 iters/sec. Estimated time to finish: 0:01:11.084421.
# validation [#############.....................................] 27.91%
#         12 iterations
#     0.4083 iters/sec. Estimated time to finish: 0:01:15.925338.
# validation [###############...................................] 30.23%
#         13 iterations
#    0.43637 iters/sec. Estimated time to finish: 0:01:08.749459.
# validation [################..................................] 32.56%
#         14 iterations
#    0.40798 iters/sec. Estimated time to finish: 0:01:11.081440.
# validation [#################.................................] 34.88%
#         15 iterations
#    0.43208 iters/sec. Estimated time to finish: 0:01:04.802783.
# validation [##################................................] 37.21%
#         16 iterations
#    0.40448 iters/sec. Estimated time to finish: 0:01:06.752755.
# validation [###################...............................] 39.53%
#         17 iterations
#    0.42543 iters/sec. Estimated time to finish: 0:01:01.114767.
# validation [####################..............................] 41.86%
#         18 iterations
#    0.40513 iters/sec. Estimated time to finish: 0:01:01.708758.
# validation [######################............................] 44.19%
#         19 iterations
#    0.42381 iters/sec. Estimated time to finish: 0:00:56.629387.
# validation [#######################...........................] 46.51%
#         20 iterations
#    0.40331 iters/sec. Estimated time to finish: 0:00:57.027603.
# validation [########################..........................] 48.84%
#         21 iterations
#     0.4201 iters/sec. Estimated time to finish: 0:00:52.368267.
# validation [#########################.........................] 51.16%
#         22 iterations
#     0.4075 iters/sec. Estimated time to finish: 0:00:51.533439.
# validation [##########################........................] 53.49%
#         23 iterations
#     0.4229 iters/sec. Estimated time to finish: 0:00:47.292536.
# validation [###########################.......................] 55.81%
#         24 iterations
#    0.40991 iters/sec. Estimated time to finish: 0:00:46.351650.
# validation [#############################.....................] 58.14%
#         25 iterations
#    0.42409 iters/sec. Estimated time to finish: 0:00:42.443670.
# validation [##############################....................] 60.47%
#         26 iterations
#    0.40958 iters/sec. Estimated time to finish: 0:00:41.505799.
# validation [###############################...................] 62.79%
#         27 iterations
#    0.42262 iters/sec. Estimated time to finish: 0:00:37.859049.
# validation [################################..................] 65.12%
#         28 iterations
#    0.41406 iters/sec. Estimated time to finish: 0:00:36.226865.
# validation [#################################.................] 67.44%
#         29 iterations
#    0.42634 iters/sec. Estimated time to finish: 0:00:32.838026.
# validation [##################################................] 69.77%
#         30 iterations
#    0.41402 iters/sec. Estimated time to finish: 0:00:31.399135.
# validation [####################################..............] 72.09%
#         31 iterations
#    0.42548 iters/sec. Estimated time to finish: 0:00:28.203143.
# validation [#####################################.............] 74.42%
#         32 iterations
#    0.41652 iters/sec. Estimated time to finish: 0:00:26.409583.
# validation [######################################............] 76.74%
#         33 iterations
#    0.42732 iters/sec. Estimated time to finish: 0:00:23.401462.
# validation [#######################################...........] 79.07%
#         34 iterations
#    0.41395 iters/sec. Estimated time to finish: 0:00:21.741821.
# validation [########################################..........] 81.40%
#         35 iterations
#    0.42404 iters/sec. Estimated time to finish: 0:00:18.865982.
# validation [#########################################.........] 83.72%
#         36 iterations
#    0.41283 iters/sec. Estimated time to finish: 0:00:16.956320.
# validation [###########################################.......] 86.05%
#         37 iterations
#    0.42235 iters/sec. Estimated time to finish: 0:00:14.206063.
# validation [############################################......] 88.37%
#         38 iterations
#    0.41154 iters/sec. Estimated time to finish: 0:00:12.149399.
# validation [#############################################.....] 90.70%
#         39 iterations
#    0.42044 iters/sec. Estimated time to finish: 0:00:09.513851.
# validation [##############################################....] 93.02%
#         40 iterations
#    0.41209 iters/sec. Estimated time to finish: 0:00:07.280005.
# validation [###############################################...] 95.35%
#         41 iterations
#    0.42065 iters/sec. Estimated time to finish: 0:00:04.754553.
# validation [################################################..] 97.67%
#         42 iterations
#    0.42254 iters/sec. Estimated time to finish: 0:00:02.366625.
# 2           684         0.000654508  0.0237983   0.0228091   1141.66
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#.................................................]  2.33%
#          1 iterations
#     2.1855 iters/sec. Estimated time to finish: 0:00:19.217933.
# validation [##................................................]  4.65%
#          2 iterations
#    0.31689 iters/sec. Estimated time to finish: 0:02:09.382272.
# validation [###...............................................]  6.98%
#          3 iterations
#    0.44704 iters/sec. Estimated time to finish: 0:01:29.477599.
# validation [####..............................................]  9.30%
#          4 iterations
#     0.3688 iters/sec. Estimated time to finish: 0:01:45.747609.
# validation [#####.............................................] 11.63%
#          5 iterations
#    0.44459 iters/sec. Estimated time to finish: 0:01:25.471628.
# validation [######............................................] 13.95%
#          6 iterations
#    0.37156 iters/sec. Estimated time to finish: 0:01:39.581171.
# validation [########..........................................] 16.28%
#          7 iterations
#    0.42283 iters/sec. Estimated time to finish: 0:01:25.140914.
# validation [#########.........................................] 18.60%
#          8 iterations
#    0.38351 iters/sec. Estimated time to finish: 0:01:31.261419.
# validation [##########........................................] 20.93%
#          9 iterations
#    0.42328 iters/sec. Estimated time to finish: 0:01:20.324157.
# validation [###########.......................................] 23.26%
#         10 iterations
#    0.38735 iters/sec. Estimated time to finish: 0:01:25.194244.
# validation [############......................................] 25.58%
#         11 iterations
#    0.41956 iters/sec. Estimated time to finish: 0:01:16.269755.
# validation [#############.....................................] 27.91%
#         12 iterations
#    0.37929 iters/sec. Estimated time to finish: 0:01:21.732239.
# validation [###############...................................] 30.23%
#         13 iterations
#    0.40578 iters/sec. Estimated time to finish: 0:01:13.932197.
# validation [################..................................] 32.56%
#         14 iterations
#     0.3842 iters/sec. Estimated time to finish: 0:01:15.481928.
# validation [#################.................................] 34.88%
#         15 iterations
#    0.40713 iters/sec. Estimated time to finish: 0:01:08.774506.
# validation [##################................................] 37.21%
#         16 iterations
#    0.39149 iters/sec. Estimated time to finish: 0:01:08.966894.
# validation [###################...............................] 39.53%
#         17 iterations
#    0.41189 iters/sec. Estimated time to finish: 0:01:03.123849.
# validation [####################..............................] 41.86%
#         18 iterations
#    0.39455 iters/sec. Estimated time to finish: 0:01:03.363709.
# validation [######################............................] 44.19%
#         19 iterations
#    0.41278 iters/sec. Estimated time to finish: 0:00:58.142234.
# validation [#######################...........................] 46.51%
#         20 iterations
#    0.39501 iters/sec. Estimated time to finish: 0:00:58.227038.
# validation [########################..........................] 48.84%
#         21 iterations
#    0.41152 iters/sec. Estimated time to finish: 0:00:53.460299.
# validation [#########################.........................] 51.16%
#         22 iterations
#    0.39963 iters/sec. Estimated time to finish: 0:00:52.547967.
# validation [##########################........................] 53.49%
#         23 iterations
#     0.4148 iters/sec. Estimated time to finish: 0:00:48.216586.
# validation [###########################.......................] 55.81%
#         24 iterations
#    0.40258 iters/sec. Estimated time to finish: 0:00:47.195284.
# validation [#############################.....................] 58.14%
#         25 iterations
#     0.4165 iters/sec. Estimated time to finish: 0:00:43.216994.
# validation [##############################....................] 60.47%
#         26 iterations
#    0.39619 iters/sec. Estimated time to finish: 0:00:42.908560.
# validation [###############################...................] 62.79%
#         27 iterations
#    0.40891 iters/sec. Estimated time to finish: 0:00:39.128684.
# validation [################################..................] 65.12%
#         28 iterations
#     0.3978 iters/sec. Estimated time to finish: 0:00:37.707755.
# validation [#################################.................] 67.44%
#         29 iterations
#    0.40962 iters/sec. Estimated time to finish: 0:00:34.178310.
# validation [##################################................] 69.77%
#         30 iterations
#    0.40083 iters/sec. Estimated time to finish: 0:00:32.432944.
# validation [####################################..............] 72.09%
#         31 iterations
#      0.412 iters/sec. Estimated time to finish: 0:00:29.126320.
# validation [#####################################.............] 74.42%
#         32 iterations
#    0.40445 iters/sec. Estimated time to finish: 0:00:27.197541.
# validation [######################################............] 76.74%
#         33 iterations
#    0.41496 iters/sec. Estimated time to finish: 0:00:24.098694.
# validation [#######################################...........] 79.07%
#         34 iterations
#     0.4042 iters/sec. Estimated time to finish: 0:00:22.266446.
# validation [########################################..........] 81.40%
#         35 iterations
#    0.41409 iters/sec. Estimated time to finish: 0:00:19.319435.
# validation [#########################################.........] 83.72%
#         36 iterations
#    0.40551 iters/sec. Estimated time to finish: 0:00:17.262322.
# validation [###########################################.......] 86.05%
#         37 iterations
#    0.41491 iters/sec. Estimated time to finish: 0:00:14.460878.
# validation [############################################......] 88.37%
#         38 iterations
#     0.4054 iters/sec. Estimated time to finish: 0:00:12.333628.
# validation [#############################################.....] 90.70%
#         39 iterations
#    0.41426 iters/sec. Estimated time to finish: 0:00:09.655656.
# validation [##############################################....] 93.02%
#         40 iterations
#    0.40979 iters/sec. Estimated time to finish: 0:00:07.320759.
# validation [###############################################...] 95.35%
#         41 iterations
#    0.41833 iters/sec. Estimated time to finish: 0:00:04.780945.
# validation [################################################..] 97.67%
#         42 iterations
#    0.42028 iters/sec. Estimated time to finish: 0:00:02.379353.
# 3           1026        0.000345492  0.0216936   0.021283    1714.28
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#.................................................]  2.33%
#          1 iterations
#     2.4787 iters/sec. Estimated time to finish: 0:00:16.944340.
# validation [##................................................]  4.65%
#          2 iterations
#    0.41366 iters/sec. Estimated time to finish: 0:01:39.114436.
# validation [###...............................................]  6.98%
#          3 iterations
#    0.57317 iters/sec. Estimated time to finish: 0:01:09.787334.
# validation [####..............................................]  9.30%
#          4 iterations
#    0.43612 iters/sec. Estimated time to finish: 0:01:29.425528.
# validation [#####.............................................] 11.63%
#          5 iterations
#    0.52243 iters/sec. Estimated time to finish: 0:01:12.737611.
# validation [######............................................] 13.95%
#          6 iterations
#    0.41528 iters/sec. Estimated time to finish: 0:01:29.096648.
# validation [########..........................................] 16.28%
#          7 iterations
#    0.47109 iters/sec. Estimated time to finish: 0:01:16.418153.
# validation [#########.........................................] 18.60%
#          8 iterations
#    0.41335 iters/sec. Estimated time to finish: 0:01:24.674811.
# validation [##########........................................] 20.93%
#          9 iterations
#    0.45565 iters/sec. Estimated time to finish: 0:01:14.618536.
# validation [###########.......................................] 23.26%
#         10 iterations
#    0.41773 iters/sec. Estimated time to finish: 0:01:18.998064.
# validation [############......................................] 25.58%
#         11 iterations
#    0.45182 iters/sec. Estimated time to finish: 0:01:10.824326.
# validation [#############.....................................] 27.91%
#         12 iterations
#    0.38197 iters/sec. Estimated time to finish: 0:01:21.159058.
# validation [###############...................................] 30.23%
#         13 iterations
#    0.40858 iters/sec. Estimated time to finish: 0:01:13.424471.
# validation [################..................................] 32.56%
#         14 iterations
#    0.38894 iters/sec. Estimated time to finish: 0:01:14.561224.
# validation [#################.................................] 34.88%
#         15 iterations
#    0.41211 iters/sec. Estimated time to finish: 0:01:07.943180.
# validation [##################................................] 37.21%
#         16 iterations
#    0.39424 iters/sec. Estimated time to finish: 0:01:08.485355.
# validation [###################...............................] 39.53%
#         17 iterations
#    0.41476 iters/sec. Estimated time to finish: 0:01:02.687416.
# validation [####################..............................] 41.86%
#         18 iterations
#    0.39765 iters/sec. Estimated time to finish: 0:01:02.869907.
# validation [######################............................] 44.19%
#         19 iterations
#    0.41607 iters/sec. Estimated time to finish: 0:00:57.683054.
# validation [#######################...........................] 46.51%
#         20 iterations
#    0.39745 iters/sec. Estimated time to finish: 0:00:57.869179.
# validation [########################..........................] 48.84%
#         21 iterations
#    0.41402 iters/sec. Estimated time to finish: 0:00:53.137782.
# validation [#########################.........................] 51.16%
#         22 iterations
#    0.40183 iters/sec. Estimated time to finish: 0:00:52.261528.
# validation [##########################........................] 53.49%
#         23 iterations
#    0.41706 iters/sec. Estimated time to finish: 0:00:47.954718.
# validation [###########################.......................] 55.81%
#         24 iterations
#    0.40028 iters/sec. Estimated time to finish: 0:00:47.466930.
# validation [#############################.....................] 58.14%
#         25 iterations
#    0.41419 iters/sec. Estimated time to finish: 0:00:43.458018.
# validation [##############################....................] 60.47%
#         26 iterations
#    0.40168 iters/sec. Estimated time to finish: 0:00:42.321836.
# validation [###############################...................] 62.79%
#         27 iterations
#    0.41458 iters/sec. Estimated time to finish: 0:00:38.593646.
# validation [################################..................] 65.12%
#         28 iterations
#    0.40409 iters/sec. Estimated time to finish: 0:00:37.120012.
# validation [#################################.................] 67.44%
#         29 iterations
#    0.41609 iters/sec. Estimated time to finish: 0:00:33.646710.
# validation [##################################................] 69.77%
#         30 iterations
#    0.40686 iters/sec. Estimated time to finish: 0:00:31.952225.
# validation [####################################..............] 72.09%
#         31 iterations
#    0.41814 iters/sec. Estimated time to finish: 0:00:28.698512.
# validation [#####################################.............] 74.42%
#         32 iterations
#    0.40999 iters/sec. Estimated time to finish: 0:00:26.830188.
# validation [######################################............] 76.74%
#         33 iterations
#    0.42064 iters/sec. Estimated time to finish: 0:00:23.773427.
# validation [#######################################...........] 79.07%
#         34 iterations
#    0.40942 iters/sec. Estimated time to finish: 0:00:21.982240.
# validation [########################################..........] 81.40%
#         35 iterations
#    0.41945 iters/sec. Estimated time to finish: 0:00:19.072396.
# validation [#########################################.........] 83.72%
#         36 iterations
#    0.40932 iters/sec. Estimated time to finish: 0:00:17.101430.
# validation [###########################################.......] 86.05%
#         37 iterations
#    0.41879 iters/sec. Estimated time to finish: 0:00:14.327022.
# validation [############################################......] 88.37%
#         38 iterations
#    0.40373 iters/sec. Estimated time to finish: 0:00:12.384606.
# validation [#############################################.....] 90.70%
#         39 iterations
#    0.41259 iters/sec. Estimated time to finish: 0:00:09.694750.
# validation [##############################################....] 93.02%
#         40 iterations
#    0.40658 iters/sec. Estimated time to finish: 0:00:07.378656.
# validation [###############################################...] 95.35%
#         41 iterations
#    0.41506 iters/sec. Estimated time to finish: 0:00:04.818553.
# validation [################################################..] 97.67%
#         42 iterations
#    0.41524 iters/sec. Estimated time to finish: 0:00:02.408274.
# 4           1368        9.54915e-05  0.0198571   0.0201113   2287.34
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#.................................................]  2.33%
#          1 iterations
#     2.4004 iters/sec. Estimated time to finish: 0:00:17.497430.
# validation [##................................................]  4.65%
#          2 iterations
#    0.42047 iters/sec. Estimated time to finish: 0:01:37.509927.
# validation [###...............................................]  6.98%
#          3 iterations
#    0.58142 iters/sec. Estimated time to finish: 0:01:08.797388.
# validation [####..............................................]  9.30%
#          4 iterations
#    0.42379 iters/sec. Estimated time to finish: 0:01:32.026585.
# validation [#####.............................................] 11.63%
#          5 iterations
#    0.50831 iters/sec. Estimated time to finish: 0:01:14.757537.
# validation [######............................................] 13.95%
#          6 iterations
#    0.41249 iters/sec. Estimated time to finish: 0:01:29.700217.
# validation [########..........................................] 16.28%
#          7 iterations
#    0.46837 iters/sec. Estimated time to finish: 0:01:16.863003.
# validation [#########.........................................] 18.60%
#          8 iterations
#    0.40186 iters/sec. Estimated time to finish: 0:01:27.094785.
# validation [##########........................................] 20.93%
#          9 iterations
#    0.44321 iters/sec. Estimated time to finish: 0:01:16.713524.
# validation [###########.......................................] 23.26%
#         10 iterations
#    0.40505 iters/sec. Estimated time to finish: 0:01:21.471030.
# validation [############......................................] 25.58%
#         11 iterations
#    0.43851 iters/sec. Estimated time to finish: 0:01:12.974982.
# validation [#############.....................................] 27.91%
#         12 iterations
#    0.38703 iters/sec. Estimated time to finish: 0:01:20.096486.
# validation [###############...................................] 30.23%
#         13 iterations
#    0.41397 iters/sec. Estimated time to finish: 0:01:12.468882.
# validation [################..................................] 32.56%
#         14 iterations
#    0.39341 iters/sec. Estimated time to finish: 0:01:13.714529.
# validation [#################.................................] 34.88%
#         15 iterations
#    0.41686 iters/sec. Estimated time to finish: 0:01:07.168495.
# validation [##################................................] 37.21%
#         16 iterations
#    0.40066 iters/sec. Estimated time to finish: 0:01:07.389613.
# validation [###################...............................] 39.53%
#         17 iterations
#    0.42146 iters/sec. Estimated time to finish: 0:01:01.689914.
# validation [####################..............................] 41.86%
#         18 iterations
#    0.40174 iters/sec. Estimated time to finish: 0:01:02.228633.
# validation [######################............................] 44.19%
#         19 iterations
#    0.42031 iters/sec. Estimated time to finish: 0:00:57.100522.
# validation [#######################...........................] 46.51%
#         20 iterations
#    0.39553 iters/sec. Estimated time to finish: 0:00:58.150498.
# validation [########################..........................] 48.84%
#         21 iterations
#      0.412 iters/sec. Estimated time to finish: 0:00:53.397785.
# validation [#########################.........................] 51.16%
#         22 iterations
#    0.39522 iters/sec. Estimated time to finish: 0:00:53.134373.
# validation [##########################........................] 53.49%
#         23 iterations
#    0.41024 iters/sec. Estimated time to finish: 0:00:48.751436.
# validation [###########################.......................] 55.81%
#         24 iterations
#    0.39735 iters/sec. Estimated time to finish: 0:00:47.816195.
# validation [#############################.....................] 58.14%
#         25 iterations
#    0.41117 iters/sec. Estimated time to finish: 0:00:43.777056.
# validation [##############################....................] 60.47%
#         26 iterations
#    0.39653 iters/sec. Estimated time to finish: 0:00:42.872030.
# validation [###############################...................] 62.79%
#         27 iterations
#    0.40928 iters/sec. Estimated time to finish: 0:00:39.093083.
# validation [################################..................] 65.12%
#         28 iterations
#    0.40102 iters/sec. Estimated time to finish: 0:00:37.405004.
# validation [#################################.................] 67.44%
#         29 iterations
#    0.41289 iters/sec. Estimated time to finish: 0:00:33.907012.
# validation [##################################................] 69.77%
#         30 iterations
#    0.40223 iters/sec. Estimated time to finish: 0:00:32.319485.
# validation [####################################..............] 72.09%
#         31 iterations
#    0.41344 iters/sec. Estimated time to finish: 0:00:29.024991.
# validation [#####################################.............] 74.42%
#         32 iterations
#     0.4045 iters/sec. Estimated time to finish: 0:00:27.193845.
# validation [######################################............] 76.74%
#         33 iterations
#    0.41505 iters/sec. Estimated time to finish: 0:00:24.093553.
# validation [#######################################...........] 79.07%
#         34 iterations
#    0.40559 iters/sec. Estimated time to finish: 0:00:22.190041.
# validation [########################################..........] 81.40%
#         35 iterations
#    0.41553 iters/sec. Estimated time to finish: 0:00:19.252449.
# validation [#########################################.........] 83.72%
#         36 iterations
#    0.40401 iters/sec. Estimated time to finish: 0:00:17.326452.
# validation [###########################################.......] 86.05%
#         37 iterations
#    0.41333 iters/sec. Estimated time to finish: 0:00:14.516139.
# validation [############################################......] 88.37%
#         38 iterations
#     0.4028 iters/sec. Estimated time to finish: 0:00:12.413027.
# validation [#############################################.....] 90.70%
#         39 iterations
#    0.41166 iters/sec. Estimated time to finish: 0:00:09.716735.
# validation [##############################################....] 93.02%
#         40 iterations
#    0.40712 iters/sec. Estimated time to finish: 0:00:07.368835.
# validation [###############################################...] 95.35%
#         41 iterations
#    0.41561 iters/sec. Estimated time to finish: 0:00:04.812245.
# validation [################################################..] 97.67%
#         42 iterations
#     0.4171 iters/sec. Estimated time to finish: 0:00:02.397495.
# 5           1710        0           0.0183729   0.0177859   2866.24
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#.................................................]  2.33%
#          1 iterations
#     2.4839 iters/sec. Estimated time to finish: 0:00:16.908842.
# validation [##................................................]  4.65%
#          2 iterations
#    0.39944 iters/sec. Estimated time to finish: 0:01:42.642771.
# validation [###...............................................]  6.98%
#          3 iterations
#    0.55453 iters/sec. Estimated time to finish: 0:01:12.133462.
# validation [####..............................................]  9.30%
#          4 iterations
#    0.41631 iters/sec. Estimated time to finish: 0:01:33.679751.
# validation [#####.............................................] 11.63%
#          5 iterations
#    0.49943 iters/sec. Estimated time to finish: 0:01:16.087017.
# validation [######............................................] 13.95%
#          6 iterations
#    0.39018 iters/sec. Estimated time to finish: 0:01:34.828063.
# validation [########..........................................] 16.28%
#          7 iterations
#    0.44362 iters/sec. Estimated time to finish: 0:01:21.150489.
# validation [#########.........................................] 18.60%
#          8 iterations
#     0.3867 iters/sec. Estimated time to finish: 0:01:30.509811.
# validation [##########........................................] 20.93%
#          9 iterations
#    0.42671 iters/sec. Estimated time to finish: 0:01:19.679691.
# validation [###########.......................................] 23.26%
#         10 iterations
#    0.38646 iters/sec. Estimated time to finish: 0:01:25.390157.
# validation [############......................................] 25.58%
#         11 iterations
#    0.41853 iters/sec. Estimated time to finish: 0:01:16.457606.
# validation [#############.....................................] 27.91%
#         12 iterations
#    0.38208 iters/sec. Estimated time to finish: 0:01:21.135071.
# validation [###############...................................] 30.23%
#         13 iterations
#    0.40872 iters/sec. Estimated time to finish: 0:01:13.399566.
# validation [################..................................] 32.56%
#         14 iterations
#    0.38693 iters/sec. Estimated time to finish: 0:01:14.948531.
# validation [#################.................................] 34.88%
#         15 iterations
#    0.40985 iters/sec. Estimated time to finish: 0:01:08.317847.
# validation [##################................................] 37.21%
#         16 iterations
#    0.39157 iters/sec. Estimated time to finish: 0:01:08.953533.
# validation [###################...............................] 39.53%
#         17 iterations
#    0.41201 iters/sec. Estimated time to finish: 0:01:03.104733.
# validation [####################..............................] 41.86%
#         18 iterations
#    0.39368 iters/sec. Estimated time to finish: 0:01:03.503567.
# validation [######################............................] 44.19%
#         19 iterations
#    0.41192 iters/sec. Estimated time to finish: 0:00:58.263210.
# validation [#######################...........................] 46.51%
#         20 iterations
#     0.3934 iters/sec. Estimated time to finish: 0:00:58.464082.
# validation [########################..........................] 48.84%
#         21 iterations
#    0.40982 iters/sec. Estimated time to finish: 0:00:53.682174.
# validation [#########################.........................] 51.16%
#         22 iterations
#    0.39665 iters/sec. Estimated time to finish: 0:00:52.943823.
# validation [##########################........................] 53.49%
#         23 iterations
#    0.41173 iters/sec. Estimated time to finish: 0:00:48.576095.
# validation [###########################.......................] 55.81%
#         24 iterations
#    0.39718 iters/sec. Estimated time to finish: 0:00:47.837095.
# validation [#############################.....................] 58.14%
#         25 iterations
#    0.41103 iters/sec. Estimated time to finish: 0:00:43.792814.
# validation [##############################....................] 60.47%
#         26 iterations
#    0.39782 iters/sec. Estimated time to finish: 0:00:42.733422.
# validation [###############################...................] 62.79%
#         27 iterations
#    0.41061 iters/sec. Estimated time to finish: 0:00:38.966411.
# validation [################################..................] 65.12%
#         28 iterations
#    0.39798 iters/sec. Estimated time to finish: 0:00:37.690415.
# validation [#################################.................] 67.44%
#         29 iterations
#    0.40988 iters/sec. Estimated time to finish: 0:00:34.156603.
# validation [##################################................] 69.77%
#         30 iterations
#    0.39605 iters/sec. Estimated time to finish: 0:00:32.824500.
# validation [####################################..............] 72.09%
#         31 iterations
#    0.40709 iters/sec. Estimated time to finish: 0:00:29.477583.
# validation [#####################################.............] 74.42%
#         32 iterations
#    0.39659 iters/sec. Estimated time to finish: 0:00:27.736225.
# validation [######################################............] 76.74%
#         33 iterations
#    0.40698 iters/sec. Estimated time to finish: 0:00:24.570967.
# validation [#######################################...........] 79.07%
#         34 iterations
#    0.39703 iters/sec. Estimated time to finish: 0:00:22.668407.
# validation [########################################..........] 81.40%
#         35 iterations
#    0.40682 iters/sec. Estimated time to finish: 0:00:19.664894.
# validation [#########################################.........] 83.72%
#         36 iterations
#    0.39645 iters/sec. Estimated time to finish: 0:00:17.656874.
# validation [###########################################.......] 86.05%
#         37 iterations
#    0.40565 iters/sec. Estimated time to finish: 0:00:14.791128.
# validation [############################################......] 88.37%
#         38 iterations
#    0.39675 iters/sec. Estimated time to finish: 0:00:12.602416.
# validation [#############################################.....] 90.70%
#         39 iterations
#    0.40551 iters/sec. Estimated time to finish: 0:00:09.864203.
# validation [##############################################....] 93.02%
#         40 iterations
#    0.40146 iters/sec. Estimated time to finish: 0:00:07.472662.
# validation [###############################################...] 95.35%
#         41 iterations
#    0.40985 iters/sec. Estimated time to finish: 0:00:04.879875.
# validation [################################################..] 97.67%
#         42 iterations
#    0.41037 iters/sec. Estimated time to finish: 0:00:02.436811.
# 6           2052        9.54915e-05  0.0170125   0.017298    3445.5
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#.................................................]  2.33%
#          1 iterations
#     2.4905 iters/sec. Estimated time to finish: 0:00:16.864121.
# validation [##................................................]  4.65%
#          2 iterations
#    0.41864 iters/sec. Estimated time to finish: 0:01:37.937218.
# validation [###...............................................]  6.98%
#          3 iterations
#    0.57928 iters/sec. Estimated time to finish: 0:01:09.051040.
# validation [####..............................................]  9.30%
#          4 iterations
#    0.41696 iters/sec. Estimated time to finish: 0:01:33.535162.
# validation [#####.............................................] 11.63%
#          5 iterations
#    0.50034 iters/sec. Estimated time to finish: 0:01:15.948741.
# validation [######............................................] 13.95%
#          6 iterations
#    0.40816 iters/sec. Estimated time to finish: 0:01:30.649749.
# validation [########..........................................] 16.28%
#          7 iterations
#    0.46356 iters/sec. Estimated time to finish: 0:01:17.659452.
# validation [#########.........................................] 18.60%
#          8 iterations
#    0.39898 iters/sec. Estimated time to finish: 0:01:27.722704.
# validation [##########........................................] 20.93%
#          9 iterations
#    0.43993 iters/sec. Estimated time to finish: 0:01:17.284851.
# validation [###########.......................................] 23.26%
#         10 iterations
#     0.3992 iters/sec. Estimated time to finish: 0:01:22.664861.
# validation [############......................................] 25.58%
#         11 iterations
#      0.432 iters/sec. Estimated time to finish: 0:01:14.074227.
# validation [#############.....................................] 27.91%
#         12 iterations
#    0.37868 iters/sec. Estimated time to finish: 0:01:21.863896.
# validation [###############...................................] 30.23%
#         13 iterations
#    0.40514 iters/sec. Estimated time to finish: 0:01:14.049109.
# validation [################..................................] 32.56%
#         14 iterations
#    0.38464 iters/sec. Estimated time to finish: 0:01:15.395137.
# validation [#################.................................] 34.88%
#         15 iterations
#    0.40765 iters/sec. Estimated time to finish: 0:01:08.685887.
# validation [##################................................] 37.21%
#         16 iterations
#    0.38976 iters/sec. Estimated time to finish: 0:01:09.273436.
# validation [###################...............................] 39.53%
#         17 iterations
#    0.41012 iters/sec. Estimated time to finish: 0:01:03.396294.
# validation [####################..............................] 41.86%
#         18 iterations
#    0.38963 iters/sec. Estimated time to finish: 0:01:04.162844.
# validation [######################............................] 44.19%
#         19 iterations
#    0.40773 iters/sec. Estimated time to finish: 0:00:58.863017.
# validation [#######################...........................] 46.51%
#         20 iterations
#     0.3882 iters/sec. Estimated time to finish: 0:00:59.247524.
# validation [########################..........................] 48.84%
#         21 iterations
#    0.40448 iters/sec. Estimated time to finish: 0:00:54.390412.
# validation [#########################.........................] 51.16%
#         22 iterations
#    0.39075 iters/sec. Estimated time to finish: 0:00:53.742116.
# validation [##########################........................] 53.49%
#         23 iterations
#    0.40558 iters/sec. Estimated time to finish: 0:00:49.312023.
# validation [###########################.......................] 55.81%
#         24 iterations
#    0.39394 iters/sec. Estimated time to finish: 0:00:48.231133.
# validation [#############################.....................] 58.14%
#         25 iterations
#    0.40765 iters/sec. Estimated time to finish: 0:00:44.155201.
# validation [##############################....................] 60.47%
#         26 iterations
#    0.39313 iters/sec. Estimated time to finish: 0:00:43.242162.
# validation [###############################...................] 62.79%
#         27 iterations
#     0.4058 iters/sec. Estimated time to finish: 0:00:39.428720.
# validation [################################..................] 65.12%
#         28 iterations
#    0.39762 iters/sec. Estimated time to finish: 0:00:37.724121.
# validation [#################################.................] 67.44%
#         29 iterations
#     0.4095 iters/sec. Estimated time to finish: 0:00:34.188357.
# validation [##################################................] 69.77%
#         30 iterations
#    0.39965 iters/sec. Estimated time to finish: 0:00:32.528680.
# validation [####################################..............] 72.09%
#         31 iterations
#    0.41077 iters/sec. Estimated time to finish: 0:00:29.213355.
# validation [#####################################.............] 74.42%
#         32 iterations
#    0.40189 iters/sec. Estimated time to finish: 0:00:27.370736.
# validation [######################################............] 76.74%
#         33 iterations
#    0.41236 iters/sec. Estimated time to finish: 0:00:24.250864.
# validation [#######################################...........] 79.07%
#         34 iterations
#    0.40044 iters/sec. Estimated time to finish: 0:00:22.475138.
# validation [########################################..........] 81.40%
#         35 iterations
#    0.41025 iters/sec. Estimated time to finish: 0:00:19.500107.
# validation [#########################################.........] 83.72%
#         36 iterations
#    0.39688 iters/sec. Estimated time to finish: 0:00:17.637725.
# validation [###########################################.......] 86.05%
#         37 iterations
#    0.40609 iters/sec. Estimated time to finish: 0:00:14.775007.
# validation [############################################......] 88.37%
#         38 iterations
#    0.39342 iters/sec. Estimated time to finish: 0:00:12.709033.
# validation [#############################################.....] 90.70%
#         39 iterations
#    0.40207 iters/sec. Estimated time to finish: 0:00:09.948536.
# validation [##############################################....] 93.02%
#         40 iterations
#    0.39787 iters/sec. Estimated time to finish: 0:00:07.540066.
# validation [###############################################...] 95.35%
#         41 iterations
#     0.4062 iters/sec. Estimated time to finish: 0:00:04.923635.
# validation [################################################..] 97.67%
#         42 iterations
#    0.40735 iters/sec. Estimated time to finish: 0:00:02.454866.
# 7           2394        0.000345492  0.0159351   0.0151453   4033.18
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# ...
#         28 iterations
#    0.42741 iters/sec. Estimated time to finish: 0:00:35.094769.
# validation [#################################.................] 67.44%
#         29 iterations
#    0.43998 iters/sec. Estimated time to finish: 0:00:31.819985.
# validation [##################################................] 69.77%
#         30 iterations
#    0.42997 iters/sec. Estimated time to finish: 0:00:30.234329.
# validation [####################################..............] 72.09%
#         31 iterations
#    0.44172 iters/sec. Estimated time to finish: 0:00:27.166369.
# validation [#####################################.............] 74.42%
#         32 iterations
#    0.43379 iters/sec. Estimated time to finish: 0:00:25.357956.
# validation [######################################............] 76.74%
#         33 iterations
#    0.44494 iters/sec. Estimated time to finish: 0:00:22.475104.
# validation [#######################################...........] 79.07%
#         34 iterations
#    0.43298 iters/sec. Estimated time to finish: 0:00:20.785967.
# validation [########################################..........] 81.40%
#         35 iterations
#    0.44345 iters/sec. Estimated time to finish: 0:00:18.040536.
# validation [#########################################.........] 83.72%
#         36 iterations
#    0.43213 iters/sec. Estimated time to finish: 0:00:16.198971.
# validation [###########################################.......] 86.05%
#         37 iterations
#    0.44201 iters/sec. Estimated time to finish: 0:00:13.574275.
# validation [############################################......] 88.37%
#         38 iterations
#     0.4275 iters/sec. Estimated time to finish: 0:00:11.696035.
# validation [#############################################.....] 90.70%
#         39 iterations
#    0.43678 iters/sec. Estimated time to finish: 0:00:09.157919.
# validation [##############################################....] 93.02%
#         40 iterations
#    0.42912 iters/sec. Estimated time to finish: 0:00:06.991112.
# validation [###############################################...] 95.35%
#         41 iterations
#    0.43798 iters/sec. Estimated time to finish: 0:00:04.566432.
# validation [################################################..] 97.67%
#         42 iterations
#    0.43966 iters/sec. Estimated time to finish: 0:00:02.274474.
# 48          16416       0.000654508  0.00307742  0.0103578   27004.1
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#.................................................]  2.33%
#          1 iterations
#     2.4956 iters/sec. Estimated time to finish: 0:00:16.829644.
# validation [##................................................]  4.65%
#          2 iterations
#      0.422 iters/sec. Estimated time to finish: 0:01:37.156256.
# validation [###...............................................]  6.98%
#          3 iterations
#    0.58405 iters/sec. Estimated time to finish: 0:01:08.487873.
# validation [####..............................................]  9.30%
#          4 iterations
#    0.43318 iters/sec. Estimated time to finish: 0:01:30.031462.
# validation [#####.............................................] 11.63%
#          5 iterations
#    0.51911 iters/sec. Estimated time to finish: 0:01:13.202832.
# validation [######............................................] 13.95%
#          6 iterations
#     0.4292 iters/sec. Estimated time to finish: 0:01:26.207224.
# validation [########..........................................] 16.28%
#          7 iterations
#    0.48644 iters/sec. Estimated time to finish: 0:01:14.006574.
# validation [#########.........................................] 18.60%
#          8 iterations
#    0.41513 iters/sec. Estimated time to finish: 0:01:24.310454.
# validation [##########........................................] 20.93%
#          9 iterations
#    0.45698 iters/sec. Estimated time to finish: 0:01:14.401361.
# validation [###########.......................................] 23.26%
#         10 iterations
#    0.41701 iters/sec. Estimated time to finish: 0:01:19.135058.
# validation [############......................................] 25.58%
#         11 iterations
#    0.45119 iters/sec. Estimated time to finish: 0:01:10.924219.
# validation [#############.....................................] 27.91%
#         12 iterations
#    0.41104 iters/sec. Estimated time to finish: 0:01:15.419227.
# validation [###############...................................] 30.23%
#         13 iterations
#     0.4392 iters/sec. Estimated time to finish: 0:01:08.306271.
# validation [################..................................] 32.56%
#         14 iterations
#    0.41481 iters/sec. Estimated time to finish: 0:01:09.911768.
# validation [#################.................................] 34.88%
#         15 iterations
#    0.43926 iters/sec. Estimated time to finish: 0:01:03.743726.
# validation [##################................................] 37.21%
#         16 iterations
#    0.42225 iters/sec. Estimated time to finish: 0:01:03.942591.
# validation [###################...............................] 39.53%
#         17 iterations
#    0.44387 iters/sec. Estimated time to finish: 0:00:58.575623.
# validation [####################..............................] 41.86%
#         18 iterations
#    0.42264 iters/sec. Estimated time to finish: 0:00:59.152413.
# validation [######################............................] 44.19%
#         19 iterations
#    0.44198 iters/sec. Estimated time to finish: 0:00:54.301127.
# validation [#######################...........................] 46.51%
#         20 iterations
#    0.42276 iters/sec. Estimated time to finish: 0:00:54.404863.
# validation [########################..........................] 48.84%
#         21 iterations
#     0.4402 iters/sec. Estimated time to finish: 0:00:49.976926.
# validation [#########################.........................] 51.16%
#         22 iterations
#    0.42373 iters/sec. Estimated time to finish: 0:00:49.559424.
# validation [##########################........................] 53.49%
#         23 iterations
#    0.43961 iters/sec. Estimated time to finish: 0:00:45.494433.
# validation [###########################.......................] 55.81%
#         24 iterations
#    0.42594 iters/sec. Estimated time to finish: 0:00:44.607015.
# validation [#############################.....................] 58.14%
#         25 iterations
#    0.44058 iters/sec. Estimated time to finish: 0:00:40.855073.
# validation [##############################....................] 60.47%
#         26 iterations
#    0.42451 iters/sec. Estimated time to finish: 0:00:40.046085.
# validation [###############################...................] 62.79%
#         27 iterations
#    0.43796 iters/sec. Estimated time to finish: 0:00:36.533075.
# validation [################################..................] 65.12%
#         28 iterations
#    0.42559 iters/sec. Estimated time to finish: 0:00:35.245124.
# validation [#################################.................] 67.44%
#         29 iterations
#    0.43812 iters/sec. Estimated time to finish: 0:00:31.954507.
# validation [##################################................] 69.77%
#         30 iterations
#    0.42689 iters/sec. Estimated time to finish: 0:00:30.453088.
# validation [####################################..............] 72.09%
#         31 iterations
#    0.43862 iters/sec. Estimated time to finish: 0:00:27.358724.
# validation [#####################################.............] 74.42%
#         32 iterations
#    0.42566 iters/sec. Estimated time to finish: 0:00:25.842508.
# validation [######################################............] 76.74%
#         33 iterations
#    0.43662 iters/sec. Estimated time to finish: 0:00:22.903187.
# validation [#######################################...........] 79.07%
#         34 iterations
#    0.42381 iters/sec. Estimated time to finish: 0:00:21.235991.
# validation [########################################..........] 81.40%
#         35 iterations
#    0.43412 iters/sec. Estimated time to finish: 0:00:18.428063.
# validation [#########################################.........] 83.72%
#         36 iterations
#    0.42203 iters/sec. Estimated time to finish: 0:00:16.586461.
# validation [###########################################.......] 86.05%
#         37 iterations
#    0.43173 iters/sec. Estimated time to finish: 0:00:13.897490.
# validation [############################################......] 88.37%
#         38 iterations
#    0.42143 iters/sec. Estimated time to finish: 0:00:11.864321.
# validation [#############################################.....] 90.70%
#         39 iterations
#    0.43061 iters/sec. Estimated time to finish: 0:00:09.289165.
# validation [##############################################....] 93.02%
#         40 iterations
#    0.42468 iters/sec. Estimated time to finish: 0:00:07.064148.
# validation [###############################################...] 95.35%
#         41 iterations
#    0.43346 iters/sec. Estimated time to finish: 0:00:04.614080.
# validation [################################################..] 97.67%
#         42 iterations
#    0.43345 iters/sec. Estimated time to finish: 0:00:02.307086.
# 49          16758       0.000904508  0.00294864  0.0107697   27558
# validation [..................................................]  0.00%
#          0 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# validation [#.................................................]  2.33%
#          1 iterations
#     2.4756 iters/sec. Estimated time to finish: 0:00:16.965328.
# validation [##................................................]  4.65%
#          2 iterations
#    0.39136 iters/sec. Estimated time to finish: 0:01:44.762515.
# validation [###...............................................]  6.98%
#          3 iterations
#    0.54448 iters/sec. Estimated time to finish: 0:01:13.464346.
# validation [####..............................................]  9.30%
#          4 iterations
#    0.41929 iters/sec. Estimated time to finish: 0:01:33.013345.
# validation [#####.............................................] 11.63%
#          5 iterations
#    0.50317 iters/sec. Estimated time to finish: 0:01:15.520807.
# validation [######............................................] 13.95%
#          6 iterations
#    0.40332 iters/sec. Estimated time to finish: 0:01:31.739017.
# validation [########..........................................] 16.28%
#          7 iterations
#    0.45828 iters/sec. Estimated time to finish: 0:01:18.554201.
# validation [#########.........................................] 18.60%
#          8 iterations
#    0.39967 iters/sec. Estimated time to finish: 0:01:27.572027.
# validation [##########........................................] 20.93%
#          9 iterations
#    0.44087 iters/sec. Estimated time to finish: 0:01:17.120362.
# validation [###########.......................................] 23.26%
#         10 iterations
#    0.40369 iters/sec. Estimated time to finish: 0:01:21.746584.
# validation [############......................................] 25.58%
#         11 iterations
#    0.43695 iters/sec. Estimated time to finish: 0:01:13.234337.
# validation [#############.....................................] 27.91%
#         12 iterations
#     0.4031 iters/sec. Estimated time to finish: 0:01:16.904133.
# validation [###############...................................] 30.23%
#         13 iterations
#     0.4309 iters/sec. Estimated time to finish: 0:01:09.621647.
# validation [################..................................] 32.56%
#         14 iterations
#    0.41083 iters/sec. Estimated time to finish: 0:01:10.588616.
# validation [#################.................................] 34.88%
#         15 iterations
#    0.43506 iters/sec. Estimated time to finish: 0:01:04.358748.
# validation [##################................................] 37.21%
#         16 iterations
#    0.41623 iters/sec. Estimated time to finish: 0:01:04.867739.
# validation [###################...............................] 39.53%
#         17 iterations
#    0.43773 iters/sec. Estimated time to finish: 0:00:59.396996.
# validation [####################..............................] 41.86%
#         18 iterations
#    0.41948 iters/sec. Estimated time to finish: 0:00:59.597573.
# validation [######################............................] 44.19%
#         19 iterations
#    0.43869 iters/sec. Estimated time to finish: 0:00:54.708784.
# validation [#######################...........................] 46.51%
#         20 iterations
#    0.41559 iters/sec. Estimated time to finish: 0:00:55.343084.
# validation [########################..........................] 48.84%
#         21 iterations
#    0.43278 iters/sec. Estimated time to finish: 0:00:50.834220.
# validation [#########################.........................] 51.16%
#         22 iterations
#    0.41954 iters/sec. Estimated time to finish: 0:00:50.054696.
# validation [##########################........................] 53.49%
#         23 iterations
#    0.43526 iters/sec. Estimated time to finish: 0:00:45.949495.
# validation [###########################.......................] 55.81%
#         24 iterations
#    0.41959 iters/sec. Estimated time to finish: 0:00:45.282268.
# validation [#############################.....................] 58.14%
#         25 iterations
#    0.43399 iters/sec. Estimated time to finish: 0:00:41.475266.
# validation [##############################....................] 60.47%
#         26 iterations
#    0.41515 iters/sec. Estimated time to finish: 0:00:40.949053.
# validation [###############################...................] 62.79%
#         27 iterations
#     0.4284 iters/sec. Estimated time to finish: 0:00:37.348634.
# validation [################################..................] 65.12%
#         28 iterations
#    0.41874 iters/sec. Estimated time to finish: 0:00:35.821398.
# validation [#################################.................] 67.44%
#         29 iterations
#    0.43093 iters/sec. Estimated time to finish: 0:00:32.487564.
# validation [##################################................] 69.77%
#         30 iterations
#    0.42093 iters/sec. Estimated time to finish: 0:00:30.884249.
# validation [####################################..............] 72.09%
#         31 iterations
#    0.43248 iters/sec. Estimated time to finish: 0:00:27.746762.
# validation [#####################################.............] 74.42%
#         32 iterations
#    0.42419 iters/sec. Estimated time to finish: 0:00:25.931693.
# validation [######################################............] 76.74%
#         33 iterations
#    0.43513 iters/sec. Estimated time to finish: 0:00:22.981415.
# validation [#######################################...........] 79.07%
#         34 iterations
#    0.42243 iters/sec. Estimated time to finish: 0:00:21.305067.
# validation [########################################..........] 81.40%
#         35 iterations
#    0.43268 iters/sec. Estimated time to finish: 0:00:18.489369.
# validation [#########################################.........] 83.72%
#         36 iterations
#    0.42356 iters/sec. Estimated time to finish: 0:00:16.526454.
# validation [###########################################.......] 86.05%
#         37 iterations
#     0.4333 iters/sec. Estimated time to finish: 0:00:13.847321.
# validation [############################################......] 88.37%
#         38 iterations
#    0.42309 iters/sec. Estimated time to finish: 0:00:11.817765.
# validation [#############################################.....] 90.70%
#         39 iterations
#    0.43226 iters/sec. Estimated time to finish: 0:00:09.253772.
# validation [##############################################....] 93.02%
#         40 iterations
#    0.42665 iters/sec. Estimated time to finish: 0:00:07.031555.
# validation [###############################################...] 95.35%
#         41 iterations
#    0.43547 iters/sec. Estimated time to finish: 0:00:04.592750.
# validation [################################################..] 97.67%
#         42 iterations
#    0.43694 iters/sec. Estimated time to finish: 0:00:02.288665.
# 50          17100       0.001       0.00304466  0.0113122   28112.5

# %%
del train_loader
del val_loader
del model
del optimizer
del scheduler
del loss_func
del manager

gc.collect()
# Out:
# 278297

# %% [markdown]
# ## save results

# %%
# %%bash
# ls /kaggle/training_output
# Out:
# log
# loss.png
# lr.png
# snapshot_epoch_1.pth
# snapshot_epoch_10.pth
# snapshot_epoch_12.pth
# snapshot_epoch_14.pth
# snapshot_epoch_15.pth
# snapshot_epoch_16.pth
# snapshot_epoch_17.pth
# snapshot_epoch_18.pth
# snapshot_epoch_2.pth
# snapshot_epoch_25.pth
# snapshot_epoch_26.pth
# snapshot_epoch_27.pth
# snapshot_epoch_29.pth
# snapshot_epoch_3.pth
# snapshot_epoch_4.pth
# snapshot_epoch_5.pth
# snapshot_epoch_6.pth
# snapshot_epoch_7.pth
# snapshot_epoch_8.pth
# snapshot_epoch_9.pth

# %%
for f_name in ["log","loss.png", "lr.png"]:
    shutil.copy(output_dir / f_name, f_name)

# %%
log = pd.read_json("log")
best_epoch = log["val/loss"].idxmin() + 1
log.iloc[[best_epoch - 1],]
# Out:
#     train/loss        lr  val/loss  epoch  iteration  elapsed_time
# 28    0.005497  0.000905  0.009534     29       9918  16530.849108

# %%
shutil.copy(output_dir / "snapshot_epoch_{}.pth".format(best_epoch), "best_model.pth")
# Out:
# 'best_model.pth'

# %%
m = get_model({
    'name': settings["model"]["name"],
    'params': {'pretrained': False, 'n_classes': 264}})
state_dict = torch.load('best_model.pth')
m.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>
