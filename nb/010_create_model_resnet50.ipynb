# %% [markdown]
# # Overvew
# - nb009を参考にrenet50を構築してみる

# %% [markdown]
# # CONST

# %% [markdown]
# # Import everything I need :)

# %% [markdown]
# # My function

# %% [markdown]
# # Preparation

# %% [markdown]
# # Execution
